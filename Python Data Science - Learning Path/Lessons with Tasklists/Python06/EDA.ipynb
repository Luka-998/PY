# %% [markdown]
# ## Session 06: Exploratory Data Analysis - EDA

# %% [markdown]
# ### 0. What do we want to do today?
#
# Our goal in **Session06** is to learn how to perform exploratory data analysis. We will:
# - load the data,
# - inspect the nature of the data,
# - use charts of different kind for representing data graphically,
# - make some conclusions based on the previous steps.

# %% [markdown]
# ### 1. Where am I?
#
# Your are (or you should be...) in the `session06` directory, where we find
# - this notebook,
# - it's HTML version,
# - another directory `_data` that contains CSV files.

# %%
import os
import pandas as pd

work_dir = os.getcwd()
print(list(work_dir.split()))

file_path = os.path.join(work_dir,'_data','airlines.csv')

data_set = pd.read_csv(file_path)
display(data_set.head(10))

#Working, great!
# Out:
# ['c:\\Users\\Admin\\dss03Python\\PY\\Python06']
#    Unnamed: 0 carrier                         name
# 0           1      9E            Endeavor Air Inc.
# 1           2      AA       American Airlines Inc.
# 2           3      AS         Alaska Airlines Inc.
# 3           4      B6              JetBlue Airways
# 4           5      DL         Delta Air Lines Inc.
# 5           6      EV     ExpressJet Airlines Inc.
# 6           7      F9       Frontier Airlines Inc.
# 7           8      FL  AirTran Airways Corporation
# 8           9      HA       Hawaiian Airlines Inc.
# 9          10      MQ                    Envoy Air

# %% [markdown]
# ### Load the libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# Today we are working with [nycflights13 dataset](https://github.com/tidyverse/nycflights13). The data in `nycflights13` were originaly provided in an R package; we have extracted all tables present to CSV files and placed them in our `_data` directory to play with. It consists of data about flights that departed all airports in NYC in 2013 (tables: `airlines`, `airports`, `weather`, `flights` and `planes`).
#
# Also includes useful metadata on airlines, airports, weather, and planes, but we will be using these in next session.

# %% [markdown]
# First things first. We shall start with loading the flight data and inspecting the data.

# %%
df = pd.read_csv('_data/flights_session06.csv', index_col=0)
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay                 carrier  flight tailnum  \
# 0             819       11.0   United Air Lines Inc.    1545  N14228
# 1             830       20.0   United Air Lines Inc.    1714  N24211
# 2             850       33.0  American Airlines Inc.    1141  N619AA
# 3            1022      -18.0         JetBlue Airways     725  N804JB
# 4             837      -25.0    Delta Air Lines Inc.     461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental     227.0      1400
# 1           La Guardia     George Bush Intercontinental     227.0      1416
# 2  John F Kennedy Intl                       Miami Intl     160.0      1089
# 3  John F Kennedy Intl                              BQN     183.0      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl     116.0       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %% [markdown]
# #### Columns (features) description
#
# - **year, month, day** - Date of departure.
# - **dep_time, arr_time** - Actual departure and arrival times (format HHMM or HMM), local tz.
# - **sched_dep_time, sched_arr_time** - Scheduled departure and arrival times (format HHMM or HMM), local tz.
# - **dep_delay, arr_delay** - Departure and arrival delays, in minutes. Negative times represent early departures/arrivals.
# - **carrier** - Originally it is two letter carrier abbreviation. For the purpose of this session it is the full name of the airline.
# - **flight** - Flight number.
# - **tailnum** - Plane tail number. See planes for additional metadata.
# - **origin, dest** - Origin and destination. Originally these are the abbreviations of airport names. This time we use full names for better understanding.
# - **air_time** - Amount of time spent in the air, in minutes.
# - **distance** - Distance between airports, in miles.
# - **hour, minute** - Time of scheduled departure broken into hour and minutes.
# - **time_hour** - Scheduled date and hour of the flight as a POSIXct date. Along with origin, can be used to join flights data to weather data.
#
# What is POSIXct date format?
# > POSIXct stores date and time in seconds with the number of seconds beginning at 1 January 1970. Negative numbers are used to store dates prior to 1970. Thus, the POSIXct format stores each date and time as a single value in units of seconds.

# %% [markdown]
# Now that we have the overview, we want to check the data for missing values.

# %% [markdown]
# ### Cleaning the data

# %%
(df.isna()
   .sum()
   .reset_index()
   .rename(columns={'index': 'feature', 0: 'no_nulls'})
   .sort_values('no_nulls', ascending=False)
   .assign(perc_nulls = lambda x: x['no_nulls'] / len(df) * 100))
# Out:
#            feature  no_nulls  perc_nulls
# 8        arr_delay      9430    2.800081
# 14        air_time      9430    2.800081
# 6         arr_time      8713    2.587180
# 3         dep_time      8255    2.451184
# 5        dep_delay      8255    2.451184
# 11         tailnum      2512    0.745896
# 0             year         0    0.000000
# 12          origin         0    0.000000
# 17          minute         0    0.000000
# 16            hour         0    0.000000
# 15        distance         0    0.000000
# 13            dest         0    0.000000
# 9          carrier         0    0.000000
# 10          flight         0    0.000000
# 1            month         0    0.000000
# 7   sched_arr_time         0    0.000000
# 4   sched_dep_time         0    0.000000
# 2              day         0    0.000000
# 18       time_hour         0    0.000000

# %% [markdown]
# Let's analyse this expression in a step by step manner.

# %% [markdown]
# #### `df.isna()`
#
# =Return a boolean same-sized object indicating if the values are NA.
# NA values, such as None or :attr:`numpy.NaN`, gets mapped to True
# values.
# Everything else gets mapped to False values

# %%
df.isna().any()
# Out:
# year              False
# month             False
# day               False
# dep_time           True
# sched_dep_time    False
# dep_delay          True
# arr_time           True
# sched_arr_time    False
# arr_delay          True
# carrier           False
# flight            False
# tailnum            True
# origin            False
# dest              False
# air_time           True
# distance          False
# hour              False
# minute            False
# time_hour         False
# dtype: bool

# %%
df.isna().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %%
df.isna().sum().reset_index()
# Out:
#              index     0
# 0             year     0
# 1            month     0
# 2              day     0
# 3         dep_time  8255
# 4   sched_dep_time     0
# 5        dep_delay  8255
# 6         arr_time  8713
# 7   sched_arr_time     0
# 8        arr_delay  9430
# 9          carrier     0
# 10          flight     0
# 11         tailnum  2512
# 12          origin     0
# 13            dest     0
# 14        air_time  9430
# 15        distance     0
# 16            hour     0
# 17          minute     0
# 18       time_hour     0

# %%
(df.isna()
    .sum()
    .reset_index()
    .rename(columns={'index': 'feature', 0:'no nulls'}))
# Out:
#            feature  no nulls
# 0             year         0
# 1            month         0
# 2              day         0
# 3         dep_time      8255
# 4   sched_dep_time         0
# 5        dep_delay      8255
# 6         arr_time      8713
# 7   sched_arr_time         0
# 8        arr_delay      9430
# 9          carrier         0
# 10          flight         0
# 11         tailnum      2512
# 12          origin         0
# 13            dest         0
# 14        air_time      9430
# 15        distance         0
# 16            hour         0
# 17          minute         0
# 18       time_hour         0

# %% [markdown]
# This is a `method chaining` pattern, where multiple methods are called in sequence.
#
# 1. `df.isna():`
#
# - This checks for missing (NaN) values in the DataFrame (df).
#
# - It returns a DataFrame of the same shape as df, with True where values are missing and False where they are not.
#
#
# 2. `.sum():`
#
# - When applied to a boolean DataFrame (like isna() output), it counts the number of True values (i.e., missing values) for each column.

# %%
(df.isna()
    .sum()
    .reset_index()
   .rename(columns={'index': 'feature', 0: 'no_nulls'})
   .sort_values('no_nulls', ascending=False))
# Out:
#            feature  no_nulls
# 8        arr_delay      9430
# 14        air_time      9430
# 6         arr_time      8713
# 3         dep_time      8255
# 5        dep_delay      8255
# 11         tailnum      2512
# 0             year         0
# 12          origin         0
# 17          minute         0
# 16            hour         0
# 15        distance         0
# 13            dest         0
# 9          carrier         0
# 10          flight         0
# 1            month         0
# 7   sched_arr_time         0
# 4   sched_dep_time         0
# 2              day         0
# 18       time_hour         0

# %% [markdown]
# And as of the following: `.assign(perc_nulls = lambda x: x['no_nulls'] / len(df) * 100))`: we need to introduce the concept of anonymous (or *lambda* functions) at this point.
#
# By now you know how to define a function. This function can be everything from a complex to a very simple one in terms of what it does.
#
# Remember the function for creating the scheme for a given string, from the previous session?
#
# ```python
# def scheme_string(s):
#     print('')
#     print('String:', s)
#     print('')
#     print('Scheme:')
#     print('|'.join(f'{x: >3}' for x in range(len(s))))
#     print(' '.join([f'{x: >3}' for x in s]))
#     print('|'.join(f'{-x: >3}' for x in range(len(s), 0, -1)))
#     print()
#     print('Length:', len(s))
# ```
#
# You could say this is not a trivial function. But, what if you wanted to create very simple function that returns square of a given value?

# %%
def square_it(a):
    return a**2
square_it(29)
# Out:
# 841

# %% [markdown]
# For the purposes of having to define simple function, maybe even for a one time use, Python introduces `*lambda*` functions. These similar to user-defined functions *except for they have no name*. We also say that a lambda function is an *anonymous function* because of that.

# %%
(lambda x: x**2)(7)
# Out:
# 49

# %%
(lambda x,y: x**y/x) (6,3)
# Out:
# 36.0

# %% [markdown]
# Lambda functions use no `return`: they will return the results of the expression. Remember: use them only for very simple things!

# %% [markdown]
# Back to our example: if we know that `pd.DataFrame.assign` assign new columns to a DataFrame (please c.f. the [Pandas documentation on pandas.DataFrame.assign](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.assign.html)), and that our DataFrame at this point looks like this:

# %%
(df.isna()
   .sum()
   .reset_index()
   .rename(columns={'index': 'feature', 0: 'no_nulls'})
   .sort_values('no_nulls', ascending=False))
# Out:
#            feature  no_nulls
# 8        arr_delay      9430
# 14        air_time      9430
# 6         arr_time      8713
# 3         dep_time      8255
# 5        dep_delay      8255
# 11         tailnum      2512
# 0             year         0
# 12          origin         0
# 17          minute         0
# 16            hour         0
# 15        distance         0
# 13            dest         0
# 9          carrier         0
# 10          flight         0
# 1            month         0
# 7   sched_arr_time         0
# 4   sched_dep_time         0
# 2              day         0
# 18       time_hour         0

# %%
df1 = df.isna().sum()\
   .reset_index()\
   .rename(columns={'index': 'feature', 0: 'no_nulls'})\
   .sort_values('no_nulls', ascending=False)

len(df1)
# Out:
# 19

# %% [markdown]
# ... then `.assign(perc_nulls = lambda x: x['no_nulls'] / len(df) * 100))` will add a new column `perc_nulls` which is computed from a lambda function (1) taking the `no_nulls` column, (2) dividing it by the number of rows of `df` returned from `len(df)`, and (3) multiplying it by 100 to obtain percents:

# %%
(df.isna()
   .sum()
   .reset_index()
   .rename(columns={'index': 'feature', 0: 'no_nulls'})
   .sort_values('no_nulls', ascending=False)
   .assign(perc_nulls = lambda x: x['no_nulls'] / len(df) * 100))
# Out:
#            feature  no_nulls  perc_nulls
# 8        arr_delay      9430    2.800081
# 14        air_time      9430    2.800081
# 6         arr_time      8713    2.587180
# 3         dep_time      8255    2.451184
# 5        dep_delay      8255    2.451184
# 11         tailnum      2512    0.745896
# 0             year         0    0.000000
# 12          origin         0    0.000000
# 17          minute         0    0.000000
# 16            hour         0    0.000000
# 15        distance         0    0.000000
# 13            dest         0    0.000000
# 9          carrier         0    0.000000
# 10          flight         0    0.000000
# 1            month         0    0.000000
# 7   sched_arr_time         0    0.000000
# 4   sched_dep_time         0    0.000000
# 2              day         0    0.000000
# 18       time_hour         0    0.000000

# %% [markdown]
# Interesting! This gives us some idea of where we have missing values. From here, you can either decide to just discard these or go investigate and maybe impute the data yourself. In cases where the percentage of missing data is very low, like in ours, you may opt to discard these right away. However, you should be careful with discarding because these percentages show you just part of the picture. What do we mean? Let's view a couple of examples.
#
# First, let's look at the visualizations of our missing data.
#
# ![](_img/missing_data_example_a.png)
#
# Here, black lines indicate missing values for each column. This also gives you part of the picture. Let's group flights with missing values and display only the columns that have missing values.
#
# ![](_img/missing_data_example_b.png)
#
# Based on this view, you can be sure that discarding flights with missing values will remove just a small portion of flights from the original data set.
#
# The scenario could easily be where missing value cells are not neatly grouped. Look at this example:
#
# ![](_img/missing_data_example_c.png)
#
# And let's do the same thing as with our data.
#
# ![](_img/missing_data_example_d.png)
#
#
# What will happen if we discard all flights with missing values using `dropna` method? Yes, we will discard more than half of our data. This is not a good start.
#
# Conclusion: **pay attention** to the missing values and be very careful when discarding them.

# %% [markdown]
# But how does Pandas handle missing values? Did we mention `None` value in Python?

# %%
type(None)
# Out:
# NoneType

# %% [markdown]
# Python has its own way of handling missing values. NumPy too. And Pandas uses NumPy for `pd.Series` values. And `pd.DataFrame` uses `pd.Series` for storing column values. So, we have to go to NumPy to see what is happening.
#
# The NumPy library has 3 different variables that are used for marking missing values (Not A Number - NAN). These are all of `float` type.

# %%
import numpy as np
type(np.NaN), type(np.NAN), type(np.nan)
# Out:
# (float, float, float)

# %% [markdown]
# If we try to compare 'nothing' with 'nothing' we get `False`. This should make sense.

# %%
np.NaN == np.NaN, np.NaN == np.nan
# Out:
# (False, False)

# %% [markdown]
# But if we try to see if they are the same objects, we see that they are. This should also make sense.

# %%
(np.NaN is np.nan, 
 np.NaN is np.NAN,  
 np.NAN is np.nan)
# Out:
# (True, True, True)

# %% [markdown]
# Why was this so important? Because when NumPy treats `NaN` values as `float`, then columns that should by their nature be of type `int`, but have missing values, are treated as `float`. This is the reason why columns that should be of type `int` but have a missing value are treated as `float`. Check it out:

# %%
null_columns = df.isna().sum().where(lambda x: x > 0).dropna().index.to_list()

# %% [markdown]
# > It’s performing a chain of operations to identify the columns with missing values (NaN) in your DataFrame (df). Let’s go step-by-step:

# %% [markdown]
# ### 1. df.isna()

# %% [markdown]
# This creates a boolean DataFrame where:
#
# -  `True` indicates a missing value (NaN).
#
# - `False` indicates a non-missing value.
#
# example:

# %%
data_example = pd.DataFrame({'A':[1,None,3],
                            'B': [None,2,3]})

data_example.rename(columns={'A':'X', 'Z':'BDC'})
data_example
# Out:
#      A    B
# 0  1.0  NaN
# 1  NaN  2.0
# 2  3.0  3.0

# %% [markdown]
# ### 2. .sum()

# %% [markdown]
# > When you call .sum() on the boolean DataFrame, it counts the number of True values in each column.
#
# - In Python, True is equivalent to 1, and False is equivalent to 0.
#
# - Therefore, summing the True values gives the total count of NaN values in each column.

# %% [markdown]
# ### 3. .where(lambda x: x > 0)
#
# The `where()` method filters the Series created by `.sum()`. It keeps values that satisfy the condition `(x > 0)` and replaces all other values with NaN.

# %%
print(df.isna().sum())
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %% [markdown]
# ### 4. .dropna()

# %% [markdown]
# This removes rows where the value is `NaN`. In this context, it drops columns that do not have any missing values.
#
# - All columns with missing values (A and B) are retained.

# %% [markdown]
# ### 5. .index.to_list()

# %% [markdown]
# Finally, `.index.to_list()` extracts the index (column names) of the remaining Series (those with missing values) and converts them into a Python list.

# %% [markdown]
# ## My full example with notes by the side:

# %%
import pandas as pd

# Sample DataFrame
data_example = pd.DataFrame({'A': [1, None, 3], 'B': [None, 2, 3], 'C': [1, 2, 3]})

# Identify columns with missing values
null_columns1 = (
    data_example.isna()                 # Step 1: Boolean DataFrame (True for NaN)
      .sum()                  # Step 2: Count NaN values in each column
      .where(lambda x: x > 0) # Step 3: Retain columns with NaN (x > 0)
      .dropna()               # Step 4: Drop columns without NaN
      .index.to_list()        # Step 5: Convert index to list of column names
)

print(null_columns1)  # Output: ['A', 'B']
# Out:
# ['A', 'B']

# %%
df[null_columns].head()
# Out:
#    dep_time  dep_delay  arr_time  arr_delay tailnum  air_time
# 0     517.0        2.0     830.0       11.0  N14228     227.0
# 1     533.0        4.0     850.0       20.0  N24211     227.0
# 2     542.0        2.0     923.0       33.0  N619AA     160.0
# 3     544.0       -1.0    1004.0      -18.0  N804JB     183.0
# 4     554.0       -6.0     812.0      -25.0  N668DN     116.0

# %%
df[null_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336776 entries, 0 to 336775
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   dep_time   328521 non-null  float64
#  1   dep_delay  328521 non-null  float64
#  2   arr_time   328063 non-null  float64
#  3   arr_delay  327346 non-null  float64
#  4   tailnum    334264 non-null  object
#  5   air_time   327346 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 18.0+ MB

# %% [markdown]
# Okay. Enough with this. Let's just drop flights that have missing values in any of the columns. We should be fine with this approach.

# %%
print(df.shape)
df = df.dropna()
print(df.shape)
# Out:
# (336776, 19)
# (327346, 19)

# %%
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay                 carrier  flight tailnum  \
# 0             819       11.0   United Air Lines Inc.    1545  N14228
# 1             830       20.0   United Air Lines Inc.    1714  N24211
# 2             850       33.0  American Airlines Inc.    1141  N619AA
# 3            1022      -18.0         JetBlue Airways     725  N804JB
# 4             837      -25.0    Delta Air Lines Inc.     461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental     227.0      1400
# 1           La Guardia     George Bush Intercontinental     227.0      1416
# 2  John F Kennedy Intl                       Miami Intl     160.0      1089
# 3  John F Kennedy Intl                              BQN     183.0      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl     116.0       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327346 entries, 0 to 336769
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            327346 non-null  int64
#  1   month           327346 non-null  int64
#  2   day             327346 non-null  int64
#  3   dep_time        327346 non-null  float64
#  4   sched_dep_time  327346 non-null  int64
#  5   dep_delay       327346 non-null  float64
#  6   arr_time        327346 non-null  float64
#  7   sched_arr_time  327346 non-null  int64
#  8   arr_delay       327346 non-null  float64
#  9   carrier         327346 non-null  object
#  10  flight          327346 non-null  int64
#  11  tailnum         327346 non-null  object
#  12  origin          327346 non-null  object
#  13  dest            327346 non-null  object
#  14  air_time        327346 non-null  float64
#  15  distance        327346 non-null  int64
#  16  hour            327346 non-null  int64
#  17  minute          327346 non-null  int64
#  18  time_hour       327346 non-null  object
# dtypes: float64(5), int64(9), object(5)
# memory usage: 49.9+ MB

# %% [markdown]
# Pandas DataFrame has a great method for trying to correctly recognize column data types. It is called `convert_dtypes`. Let's see what the result is.

# %%
df = df.convert_dtypes()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327346 entries, 0 to 336769
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            327346 non-null  Int64
#  1   month           327346 non-null  Int64
#  2   day             327346 non-null  Int64
#  3   dep_time        327346 non-null  Int64
#  4   sched_dep_time  327346 non-null  Int64
#  5   dep_delay       327346 non-null  Int64
#  6   arr_time        327346 non-null  Int64
#  7   sched_arr_time  327346 non-null  Int64
#  8   arr_delay       327346 non-null  Int64
#  9   carrier         327346 non-null  string
#  10  flight          327346 non-null  Int64
#  11  tailnum         327346 non-null  string
#  12  origin          327346 non-null  string
#  13  dest            327346 non-null  string
#  14  air_time        327346 non-null  Int64
#  15  distance        327346 non-null  Int64
#  16  hour            327346 non-null  Int64
#  17  minute          327346 non-null  Int64
#  18  time_hour       327346 non-null  string
# dtypes: Int64(14), string(5)
# memory usage: 54.3 MB

# %% [markdown]
# Voila. Once we removed `NaN` values, Pandas recognized all of the numeric columns as `int` data types. Also, columns of type "object" are now of type "string".

# %%
df.select_dtypes('int64').head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1       517             515          2       830
# 1  2013      1    1       533             529          4       850
# 2  2013      1    1       542             540          2       923
# 3  2013      1    1       544             545         -1      1004
# 4  2013      1    1       554             600         -6       812
#
#    sched_arr_time  arr_delay  flight  air_time  distance  hour  minute
# 0             819         11    1545       227      1400     5      15
# 1             830         20    1714       227      1416     5      29
# 2             850         33    1141       160      1089     5      40
# 3            1022        -18     725       183      1576     5      45
# 4             837        -25     461       116       762     6       0

# %% [markdown]
# What can we conclude based on this subset of "integer" columns?
#
# Well, here is what we can see:
# - `year`, `month`, `day`, `hour` and `minute` are surely integers, but there is hardly any point in doing arithmetic operations with them. These are not categorical either. Maybe we can observe them as ordinal-type variables?
# - `sched_dep_time` and `sched_arr_time` have a specific format, i.e., HHMM or HMM, and are not to be viewed as integers. We have to deal with this somehow.
# - `flight` is the number of the flight. This should be a nominal (categorical) variable or just a string.
# - `dep_delay` is the delay in minutes. We can use this as is.
# - `air_time` is, as the name says, airplane air time in minutes.
# - `dep_time` and `arr_time` are of the same format as `sched_dep_time` and `sched_arr_time`. We have to deal with them properly.

# %% [markdown]
# What `dep_time` and `arr_time` actually stands for?
#
# > The **departure time** is the moment that your plane **pushes back from the gate**, not the time it takes off.
#
# > The **arrival time** is the moment that your plane **pulls into the gate**, not the time it touches down on the runway.

# %% [markdown]
# Let's look at the columns of `string` type.

# %%
df.select_dtypes('string')
# Out:
#                        carrier tailnum               origin  \
# 0        United Air Lines Inc.  N14228  Newark Liberty Intl
# 1        United Air Lines Inc.  N24211           La Guardia
# 2       American Airlines Inc.  N619AA  John F Kennedy Intl
# 3              JetBlue Airways  N804JB  John F Kennedy Intl
# 4         Delta Air Lines Inc.  N668DN           La Guardia
# ...                        ...     ...                  ...
# 336765         JetBlue Airways  N354JB  John F Kennedy Intl
# 336766         JetBlue Airways  N281JB  John F Kennedy Intl
# 336767         JetBlue Airways  N346JB  John F Kennedy Intl
# 336768         JetBlue Airways  N565JB  John F Kennedy Intl
# 336769         JetBlue Airways  N516JB  John F Kennedy Intl
#
#                                       dest            time_hour
# 0             George Bush Intercontinental  2013-01-01 05:00:00
# 1             George Bush Intercontinental  2013-01-01 05:00:00
# 2                               Miami Intl  2013-01-01 05:00:00
# 3                                      BQN  2013-01-01 05:00:00
# 4          Hartsfield Jackson Atlanta Intl  2013-01-01 06:00:00
# ...                                    ...                  ...
# 336765               Syracuse Hancock Intl  2013-09-30 22:00:00
# 336766                Buffalo Niagara Intl  2013-09-30 22:00:00
# 336767              Greater Rochester Intl  2013-09-30 22:00:00
# 336768  General Edward Lawrence Logan Intl  2013-09-30 22:00:00
# 336769                                 PSE  2013-09-30 23:00:00
#
# [327346 rows x 5 columns]

# %% [markdown]
# Okay, this mostly makes sense, except for this `time_hour` column. We already said this is a special column for joining the rest of the data, stored in other CSV files in `_data` folder. The good thing about Pandas is that it can easily parse this as a date and time. Let's just give it a quick demo:

# %%
_time_hour = pd.to_datetime(df['time_hour'])
_time_hour
# Out:
# 0        2013-01-01 05:00:00
# 1        2013-01-01 05:00:00
# 2        2013-01-01 05:00:00
# 3        2013-01-01 05:00:00
# 4        2013-01-01 06:00:00
#                  ...
# 336765   2013-09-30 22:00:00
# 336766   2013-09-30 22:00:00
# 336767   2013-09-30 22:00:00
# 336768   2013-09-30 22:00:00
# 336769   2013-09-30 23:00:00
# Name: time_hour, Length: 327346, dtype: datetime64[ns]

# %% [markdown]
# Okay, big deal. What is the benefit of this? Well, you can work with this in a very interesting way.

# %%
_time_hour.dt.hour.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    6
# Name: time_hour, dtype: int32

# %%
_time_hour.dt.year.head()
# Out:
# 0    2013
# 1    2013
# 2    2013
# 3    2013
# 4    2013
# Name: time_hour, dtype: int32

# %%
_time_hour.dt.strftime('%Y-%m-%d').head()
# Out:
# 0    2013-01-01
# 1    2013-01-01
# 2    2013-01-01
# 3    2013-01-01
# 4    2013-01-01
# Name: time_hour, dtype: object

# %%
_time_hour.dt.strftime('%H-%M-%S').head()
# Out:
# 0    05-00-00
# 1    05-00-00
# 2    05-00-00
# 3    05-00-00
# 4    06-00-00
# Name: time_hour, dtype: object

# %%
(_time_hour - pd.Timedelta('10 days')).head()
# Out:
# 0   2012-12-22 05:00:00
# 1   2012-12-22 05:00:00
# 2   2012-12-22 05:00:00
# 3   2012-12-22 05:00:00
# 4   2012-12-22 06:00:00
# Name: time_hour, dtype: datetime64[ns]

# %% [markdown]
# Working with date and time is a separate course in itself. This was just a small showoff just for you to get the feel of what you can do with the datetime type of column.
#
# Ok, let's get back to our data set. Let's refresh our memory of the data set's content.

# %%
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1       517             515          2       830
# 1  2013      1    1       533             529          4       850
# 2  2013      1    1       542             540          2       923
# 3  2013      1    1       544             545         -1      1004
# 4  2013      1    1       554             600         -6       812
#
#    sched_arr_time  arr_delay                 carrier  flight tailnum  \
# 0             819         11   United Air Lines Inc.    1545  N14228
# 1             830         20   United Air Lines Inc.    1714  N24211
# 2             850         33  American Airlines Inc.    1141  N619AA
# 3            1022        -18         JetBlue Airways     725  N804JB
# 4             837        -25    Delta Air Lines Inc.     461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental       227      1400
# 1           La Guardia     George Bush Intercontinental       227      1416
# 2  John F Kennedy Intl                       Miami Intl       160      1089
# 3  John F Kennedy Intl                              BQN       183      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl       116       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %% [markdown]
# Let's do some column data type conversion. Remember, some of the columns are mistakenly "recognized" as being of the numeric type and should be converted to either string (object) or category.

# %%
df = df.astype({'flight': 'string'})

# %% [markdown]
# `df.astype()` method can be used to convert the data type of a column (or multiple columns) in a DataFrame.

# %%
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1       517             515          2       830
# 1  2013      1    1       533             529          4       850
# 2  2013      1    1       542             540          2       923
# 3  2013      1    1       544             545         -1      1004
# 4  2013      1    1       554             600         -6       812
#
#    sched_arr_time  arr_delay                 carrier flight tailnum  \
# 0             819         11   United Air Lines Inc.   1545  N14228
# 1             830         20   United Air Lines Inc.   1714  N24211
# 2             850         33  American Airlines Inc.   1141  N619AA
# 3            1022        -18         JetBlue Airways    725  N804JB
# 4             837        -25    Delta Air Lines Inc.    461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental       227      1400
# 1           La Guardia     George Bush Intercontinental       227      1416
# 2  John F Kennedy Intl                       Miami Intl       160      1089
# 3  John F Kennedy Intl                              BQN       183      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl       116       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327346 entries, 0 to 336769
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            327346 non-null  Int64
#  1   month           327346 non-null  Int64
#  2   day             327346 non-null  Int64
#  3   dep_time        327346 non-null  Int64
#  4   sched_dep_time  327346 non-null  Int64
#  5   dep_delay       327346 non-null  Int64
#  6   arr_time        327346 non-null  Int64
#  7   sched_arr_time  327346 non-null  Int64
#  8   arr_delay       327346 non-null  Int64
#  9   carrier         327346 non-null  string
#  10  flight          327346 non-null  string
#  11  tailnum         327346 non-null  string
#  12  origin          327346 non-null  string
#  13  dest            327346 non-null  string
#  14  air_time        327346 non-null  Int64
#  15  distance        327346 non-null  Int64
#  16  hour            327346 non-null  Int64
#  17  minute          327346 non-null  Int64
#  18  time_hour       327346 non-null  string
# dtypes: Int64(13), string(6)
# memory usage: 54.0 MB

# %% [markdown]
# Let's quickly see if there are duplicate rows. This is also very important.

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# ### 1. `.duplicated()`

# %% [markdown]
# The `.duplicated()` method checks for duplicate rows in your DataFrame or Series. It returns a boolean Series, where:
#
# - True means the row is a duplicate of a previous row.
#
# - False means the row is unique so far.

# %% [markdown]
# ### 2. `.any()`

# %% [markdown]
# The `.any()` method checks if any value in a Series or DataFrame is True. It returns a single boolean value:
#
# - True: If at least one True is present in the Series/DataFrame.
#
# - False: If all values are False

# %% [markdown]
# #### 3. `.duplicated().any()` Together
#
# ##### If any rows in the DataFrame are duplicates.

# %%
import pandas as pd

# Sample DataFrame
df3 = pd.DataFrame({'A': [1, 2, 2, 4], 'B': [5, 6, 6, 8]})
display(df3)
print(df3.shape)
print(df3.duplicated().any())
# Out:
#    A  B
# 0  1  5
# 1  2  6
# 2  2  6
# 3  4  8
# (4, 2)
# True

# %% [markdown]
# Now we are ready to do some data exploration!
#
# - So far, this is our dataset:

# %%
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1       517             515          2       830
# 1  2013      1    1       533             529          4       850
# 2  2013      1    1       542             540          2       923
# 3  2013      1    1       544             545         -1      1004
# 4  2013      1    1       554             600         -6       812
#
#    sched_arr_time  arr_delay                 carrier flight tailnum  \
# 0             819         11   United Air Lines Inc.   1545  N14228
# 1             830         20   United Air Lines Inc.   1714  N24211
# 2             850         33  American Airlines Inc.   1141  N619AA
# 3            1022        -18         JetBlue Airways    725  N804JB
# 4             837        -25    Delta Air Lines Inc.    461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental       227      1400
# 1           La Guardia     George Bush Intercontinental       227      1416
# 2  John F Kennedy Intl                       Miami Intl       160      1089
# 3  John F Kennedy Intl                              BQN       183      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl       116       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327346 entries, 0 to 336769
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            327346 non-null  Int64
#  1   month           327346 non-null  Int64
#  2   day             327346 non-null  Int64
#  3   dep_time        327346 non-null  Int64
#  4   sched_dep_time  327346 non-null  Int64
#  5   dep_delay       327346 non-null  Int64
#  6   arr_time        327346 non-null  Int64
#  7   sched_arr_time  327346 non-null  Int64
#  8   arr_delay       327346 non-null  Int64
#  9   carrier         327346 non-null  string
#  10  flight          327346 non-null  string
#  11  tailnum         327346 non-null  string
#  12  origin          327346 non-null  string
#  13  dest            327346 non-null  string
#  14  air_time        327346 non-null  Int64
#  15  distance        327346 non-null  Int64
#  16  hour            327346 non-null  Int64
#  17  minute          327346 non-null  Int64
#  18  time_hour       327346 non-null  string
# dtypes: Int64(13), string(6)
# memory usage: 54.0 MB

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327346 entries, 0 to 327345
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            327346 non-null  Int64
#  1   month           327346 non-null  Int64
#  2   day             327346 non-null  Int64
#  3   dep_time        327346 non-null  Int64
#  4   sched_dep_time  327346 non-null  Int64
#  5   dep_delay       327346 non-null  Int64
#  6   arr_time        327346 non-null  Int64
#  7   sched_arr_time  327346 non-null  Int64
#  8   arr_delay       327346 non-null  Int64
#  9   carrier         327346 non-null  string
#  10  flight          327346 non-null  string
#  11  tailnum         327346 non-null  string
#  12  origin          327346 non-null  string
#  13  dest            327346 non-null  string
#  14  air_time        327346 non-null  Int64
#  15  distance        327346 non-null  Int64
#  16  hour            327346 non-null  Int64
#  17  minute          327346 non-null  Int64
#  18  time_hour       327346 non-null  string
# dtypes: Int64(13), string(6)
# memory usage: 51.5 MB

# %% [markdown]
# #### Contigency tables

# %% [markdown]
# So far we know that flight origins are from the NYC airports.
#
# Let us say we want to know frequencies of flights for each carrier per airport of departure.
#
# This is a place and time to introduce `contigency tables`.
#
# We use them to show frequencies for combinations of two categorical variables. These are also referred to as *crosstabulations* or *two-way tables*. In Pandas we create them by using library's `crosstab` function, by specifying which column's values will be forming the crosstab's rows (index) or columns (columns).
#
# In our case we are going to use columns **carrier** and **origin**.
#
# ***

# %% [markdown]
# 1. `pd.crosstab` is a Pandas function used to create contingency tables, which summarize the relationship between two or more categorical variables.
#
# > basic syntax as:
#
# pd.crosstab(index, columns, values=None, aggfunc=None, margins=False, normalize=False)
#
# - index: The rows of the table (categorical variable).
#
# - columns: The columns of the table (another categorical variable).
#
# - values (optional): A column to aggregate (e.g., count, sum).
#
# - aggfunc (optional): Aggregation function (e.g., sum, mean).
#
# - margins (optional): If True, adds row/column totals.
#
# - normalize (optional): Normalizes the table (e.g., percentages).

# %%
pd.crosstab(index = df['carrier'],columns =df['origin'])
# Out:
# origin                       John F Kennedy Intl  La Guardia           \
# carrier
# AirTran Airways Corporation                    0                 3175
# Alaska Airlines Inc.                           0                    0
# American Airlines Inc.                     13600                14984
# Delta Air Lines Inc.                       20559                22804
# Endeavor Air Inc.                          13742                 2359
# Envoy Air                                   6838                16102
# ExpressJet Airlines Inc.                    1326                 8225
# Frontier Airlines Inc.                         0                  681
# Hawaiian Airlines Inc.                       342                    0
# JetBlue Airways                            41666                 5911
# Mesa Airlines Inc.                             0                  544
# SkyWest Airlines Inc.                          0                   23
# Southwest Airlines Co.                         0                 5988
# US Airways Inc.                             2964                12541
# United Air Lines Inc.                       4478                 7803
# Virgin America                              3564                    0
#
# origin                       Newark Liberty Intl
# carrier
# AirTran Airways Corporation                    0
# Alaska Airlines Inc.                         709
# American Airlines Inc.                      3363
# Delta Air Lines Inc.                        4295
# Endeavor Air Inc.                           1193
# Envoy Air                                   2097
# ExpressJet Airlines Inc.                   41557
# Frontier Airlines Inc.                         0
# Hawaiian Airlines Inc.                         0
# JetBlue Airways                             6472
# Mesa Airlines Inc.                             0
# SkyWest Airlines Inc.                          6
# Southwest Airlines Co.                      6056
# US Airways Inc.                             4326
# United Air Lines Inc.                      45501
# Virgin America                              1552

# %% [markdown]
# But how does Pandas create this table? Well, we will see exact steps in next session, but for now we can say that this looks like some sort of grouping, right?
#
# Let's refresh our memory of using `groupby` method.

# %%
# display first 10 rows
df.groupby(['carrier', 'origin'])['air_time']\
  .count()\
  .reset_index()[:10]

# but why 'air_time'?
# Out:
#                        carrier               origin  air_time
# 0  AirTran Airways Corporation           La Guardia      3175
# 1         Alaska Airlines Inc.  Newark Liberty Intl       709
# 2       American Airlines Inc.  John F Kennedy Intl     13600
# 3       American Airlines Inc.           La Guardia     14984
# 4       American Airlines Inc.  Newark Liberty Intl      3363
# 5         Delta Air Lines Inc.  John F Kennedy Intl     20559
# 6         Delta Air Lines Inc.           La Guardia     22804
# 7         Delta Air Lines Inc.  Newark Liberty Intl      4295
# 8            Endeavor Air Inc.  John F Kennedy Intl     13742
# 9            Endeavor Air Inc.           La Guardia      2359

# %% [markdown]
# There are many ways crosstabs can be created and we already showed one.
#
# Here is another:

# %%
pd.crosstab(index=df['carrier'], columns=df['origin'], normalize='index')
# Out:
# origin                       John F Kennedy Intl  La Guardia           \
# carrier
# AirTran Airways Corporation             0.000000             1.000000
# Alaska Airlines Inc.                    0.000000             0.000000
# American Airlines Inc.                  0.425705             0.469027
# Delta Air Lines Inc.                    0.431386             0.478493
# Endeavor Air Inc.                       0.794611             0.136406
# Envoy Air                               0.273116             0.643128
# ExpressJet Airlines Inc.                0.025945             0.160934
# Frontier Airlines Inc.                  0.000000             1.000000
# Hawaiian Airlines Inc.                  1.000000             0.000000
# JetBlue Airways                         0.770893             0.109364
# Mesa Airlines Inc.                      0.000000             1.000000
# SkyWest Airlines Inc.                   0.000000             0.793103
# Southwest Airlines Co.                  0.000000             0.497177
# US Airways Inc.                         0.149463             0.632394
# United Air Lines Inc.                   0.077498             0.135042
# Virgin America                          0.696638             0.000000
#
# origin                       Newark Liberty Intl
# carrier
# AirTran Airways Corporation             0.000000
# Alaska Airlines Inc.                    1.000000
# American Airlines Inc.                  0.105268
# Delta Air Lines Inc.                    0.090121
# Endeavor Air Inc.                       0.068983
# Envoy Air                               0.083756
# ExpressJet Airlines Inc.                0.813121
# Frontier Airlines Inc.                  0.000000
# Hawaiian Airlines Inc.                  0.000000
# JetBlue Airways                         0.119743
# Mesa Airlines Inc.                      0.000000
# SkyWest Airlines Inc.                   0.206897
# Southwest Airlines Co.                  0.502823
# US Airways Inc.                         0.218143
# United Air Lines Inc.                   0.787460
# Virgin America                          0.303362

# %% [markdown]
# This is very hard to read, right? There are better ways to present this table so it is easier to read it. We will get to this part.

# %% [markdown]
# We did normalize by rows, but what if we want to normalize by columns?

# %% [markdown]
# If we want to add totals per rows and columns we can do it with:

# %%
pd.crosstab(index=df['carrier'], columns=df['origin'], margins=True)
# Out:
# origin                       John F Kennedy Intl  La Guardia           \
# carrier
# AirTran Airways Corporation                    0                 3175
# Alaska Airlines Inc.                           0                    0
# American Airlines Inc.                     13600                14984
# Delta Air Lines Inc.                       20559                22804
# Endeavor Air Inc.                          13742                 2359
# Envoy Air                                   6838                16102
# ExpressJet Airlines Inc.                    1326                 8225
# Frontier Airlines Inc.                         0                  681
# Hawaiian Airlines Inc.                       342                    0
# JetBlue Airways                            41666                 5911
# Mesa Airlines Inc.                             0                  544
# SkyWest Airlines Inc.                          0                   23
# Southwest Airlines Co.                         0                 5988
# US Airways Inc.                             2964                12541
# United Air Lines Inc.                       4478                 7803
# Virgin America                              3564                    0
# All                                       109079               101140
#
# origin                       Newark Liberty Intl  All
# carrier
# AirTran Airways Corporation                    0                 3175
# Alaska Airlines Inc.                         709                  709
# American Airlines Inc.                      3363                31947
# Delta Air Lines Inc.                        4295                47658
# Endeavor Air Inc.                           1193                17294
# Envoy Air                                   2097                25037
# ExpressJet Airlines Inc.                   41557                51108
# Frontier Airlines Inc.                         0                  681
# Hawaiian Airlines Inc.                         0                  342
# JetBlue Airways                             6472                54049
# Mesa Airlines Inc.                             0                  544
# SkyWest Airlines Inc.                          6                   29
# Southwest Airlines Co.                      6056                12044
# US Airways Inc.                             4326                19831
# United Air Lines Inc.                      45501                57782
# Virgin America                              1552                 5116
# All                                       117127               327346

# %% [markdown]
# Let's sort this table by the sum of all flights for each airline.

# %%
pd.crosstab(index=df['carrier'], columns=df['origin'], margins=True)\
  .sort_values(by='All', ascending=False)
# Out:
# origin                       John F Kennedy Intl  La Guardia           \
# carrier
# All                                       109079               101140
# United Air Lines Inc.                       4478                 7803
# JetBlue Airways                            41666                 5911
# ExpressJet Airlines Inc.                    1326                 8225
# Delta Air Lines Inc.                       20559                22804
# American Airlines Inc.                     13600                14984
# Envoy Air                                   6838                16102
# US Airways Inc.                             2964                12541
# Endeavor Air Inc.                          13742                 2359
# Southwest Airlines Co.                         0                 5988
# Virgin America                              3564                    0
# AirTran Airways Corporation                    0                 3175
# Alaska Airlines Inc.                           0                    0
# Frontier Airlines Inc.                         0                  681
# Mesa Airlines Inc.                             0                  544
# Hawaiian Airlines Inc.                       342                    0
# SkyWest Airlines Inc.                          0                   23
#
# origin                       Newark Liberty Intl  All
# carrier
# All                                       117127               327346
# United Air Lines Inc.                      45501                57782
# JetBlue Airways                             6472                54049
# ExpressJet Airlines Inc.                   41557                51108
# Delta Air Lines Inc.                        4295                47658
# American Airlines Inc.                      3363                31947
# Envoy Air                                   2097                25037
# US Airways Inc.                             4326                19831
# Endeavor Air Inc.                           1193                17294
# Southwest Airlines Co.                      6056                12044
# Virgin America                              1552                 5116
# AirTran Airways Corporation                    0                 3175
# Alaska Airlines Inc.                         709                  709
# Frontier Airlines Inc.                         0                  681
# Mesa Airlines Inc.                             0                  544
# Hawaiian Airlines Inc.                         0                  342
# SkyWest Airlines Inc.                          6                   29

# %% [markdown]
# So far, we used crosstabs for showing frequencies, i.e., flights counts. Can we show highest departure delay for the same categorical variables?

# %%
pd.crosstab(index=df['carrier'],
            columns=df['origin'],
            values=df['dep_delay'],
            aggfunc=np.max)
# Out:
# origin                       John F Kennedy Intl  La Guardia           \
# carrier
# AirTran Airways Corporation                 <NA>                  602
# Alaska Airlines Inc.                        <NA>                 <NA>
# American Airlines Inc.                      1014                  803
# Delta Air Lines Inc.                         960                  911
# Endeavor Air Inc.                            747                  309
# Envoy Air                                   1137                  366
# ExpressJet Airlines Inc.                     536                  520
# Frontier Airlines Inc.                      <NA>                  853
# Hawaiian Airlines Inc.                      1301                 <NA>
# JetBlue Airways                              453                  392
# Mesa Airlines Inc.                          <NA>                  387
# SkyWest Airlines Inc.                       <NA>                  154
# Southwest Airlines Co.                      <NA>                  471
# US Airways Inc.                              374                  500
# United Air Lines Inc.                        364                  483
# Virgin America                               629                 <NA>
#
# origin                       Newark Liberty Intl
# carrier
# AirTran Airways Corporation                 <NA>
# Alaska Airlines Inc.                         225
# American Airlines Inc.                       896
# Delta Air Lines Inc.                         849
# Endeavor Air Inc.                            348
# Envoy Air                                   1126
# ExpressJet Airlines Inc.                     548
# Frontier Airlines Inc.                      <NA>
# Hawaiian Airlines Inc.                      <NA>
# JetBlue Airways                              502
# Mesa Airlines Inc.                          <NA>
# SkyWest Airlines Inc.                        131
# Southwest Airlines Co.                       440
# US Airways Inc.                              486
# United Air Lines Inc.                        424
# Virgin America                               653

# %% [markdown]
# What happens here?
#
# Well, for each group (table cell) Pandas provides a Series of **dep_delay** values.
#
# Then `aggfunc` is called upon it and the result is displayed in the table accordingly.
#
# Crosstabs are realy powerful!

# %% [markdown]
# And now visualizations!!

# %% [markdown]
# #### Visualizations

# %% [markdown]
# We already had some practice with visualizing the data from `pd.DataFrame`. Remember:

# %%
df['carrier'].value_counts().plot(kind='barh', title='Number of flights per carrier');

# %% [markdown]
# Even though this approach is quick and easy, it is used mostly for simple visuals. It also uses `matplotlib` library for drawing the elements on the image.
#
# There are many ways you can use `matplotlib` to draw desired visuals, and there are also many libraries that use `matplotlib` as a base while adding more user-friendly methods. One of which is `seaborn` which we are going to use too.
#
# But first, let's discuss some beginner steps for using `matplotlib`.
#
# When trying to draw (plot) a chart using `matplotlib`, everything is organized in one `Figure`. There are many parts to the figure, and the most important ones are depicted in [this](https://matplotlib.org/stable/tutorials/introductory/quick_start.html#parts-of-a-figure) section of official matplotlib documentation.

# %% [markdown]
# Nothing beats practice. Let's plot the example of a quadratic function.

# %%
x = np.linspace(0,50,100)
y = x**2

# %%
fig,ax = plt.subplots()
ax.plot(x,y)
plt.show()

# %% [markdown]
# Can we do it simpler? Yes!

# %%
fig, ax = plt.subplots()
ax.plot(x,x**2)
plt.show()

# %% [markdown]
# What about if `x` is in range (-50, 50)?
#
# And what if we omit calling `plt.show()`?

# %%
x = np.linspace(-50, 50, 100)

# %%
fig, ax = plt.subplots()
ax.plot(x,x**2)

# %% [markdown]
# From these examples, it is evident that:
# - we first have to create `Figure` and  `Axes` objects. Figure holds every part of the drawing.
# - `Axes` hold every part of the graph (charting area), and this includes the "coordinate system", multiple `Axis` (2, 3), x and y labels, ticks, grid, etc.
# - We use the `ax` instance of `Axes` object and call its `plot` method that is plotting the line of our function.

# %% [markdown]
# Like the official `matplotlib` [figure](https://matplotlib.org/stable/tutorials/introductory/quick_start.html#parts-of-a-figure) shows:
# - `Axis` is what defines a "coordinate" system. Most of the time, we will be working with 2D charts, so we will have X and Y axes.
# - `Axis` holds axis labels and minor and major ticks.
# - `Axes` also has a title, legend, grid, and spines.
#
#
# Let's see how this is plotted, and let's use our data.

# %%
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1       517             515          2       830
# 1  2013      1    1       533             529          4       850
# 2  2013      1    1       542             540          2       923
# 3  2013      1    1       544             545         -1      1004
# 4  2013      1    1       554             600         -6       812
#
#    sched_arr_time  arr_delay                 carrier flight tailnum  \
# 0             819         11   United Air Lines Inc.   1545  N14228
# 1             830         20   United Air Lines Inc.   1714  N24211
# 2             850         33  American Airlines Inc.   1141  N619AA
# 3            1022        -18         JetBlue Airways    725  N804JB
# 4             837        -25    Delta Air Lines Inc.    461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental       227      1400
# 1           La Guardia     George Bush Intercontinental       227      1416
# 2  John F Kennedy Intl                       Miami Intl       160      1089
# 3  John F Kennedy Intl                              BQN       183      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl       116       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %% [markdown]
# Let's plot the number of flights per each carrier.

# %%
_df = df['carrier'].value_counts()\
                    .reset_index()\
                    .rename(columns={'index':'carrier',
                                    'carrier':'no_off_flights'})
_df
# Out:
#                  no_off_flights  count
# 0         United Air Lines Inc.  57782
# 1               JetBlue Airways  54049
# 2      ExpressJet Airlines Inc.  51108
# 3          Delta Air Lines Inc.  47658
# 4        American Airlines Inc.  31947
# 5                     Envoy Air  25037
# 6               US Airways Inc.  19831
# 7             Endeavor Air Inc.  17294
# 8        Southwest Airlines Co.  12044
# 9                Virgin America   5116
# 10  AirTran Airways Corporation   3175
# 11         Alaska Airlines Inc.    709
# 12       Frontier Airlines Inc.    681
# 13           Mesa Airlines Inc.    544
# 14       Hawaiian Airlines Inc.    342
# 15        SkyWest Airlines Inc.     29

# %%
fig,ax=plt.subplots()
ax.barh(y='carrier', width='no_of_flights', data=_df)
ax.set_title('Number of flights per each carrier', size=20, pad=20)
ax.grid(alpha=0.5)
ax.invert_yaxis # ATTENTION !
# Out:
# <bound method _AxesBase.invert_yaxis of <Axes: title={'center': 'Number of flights per each carrier'}>>

# %% [markdown]
# What about if we draw it horizontally and make the figure a bit wider?

# %%
fig,ax= plt.subplots(figsize=(15,4))

ax.boxplot(df['air_time'],vert=False)
ax.grid(alpha=0.3) # Lines like a cage behind the plot. Higher the alpha, thicker the lines. 0.3 is good because it does not affect the plot lines visibility. 
ax.set_title('Boxplot for air_time column.', size=20, pad=20) 
ax.set_xticks(np.arange(0, df.air_time.max()+20, 20)); # np.arange(start,stop,step)
ax.set_ylabel('air_time')
ax.set_yticks([]);

##

fig, ax = plt.subplots()
ax.bar(x='carrier', height='no_of_flights', data=_df)
ax.set_title('Number of flights per each carrier', size=20, pad=20)
ax.grid(alpha=.5)
ax.set_xlabel('Carrier')
ax.set_ylabel('# of flights');

# %% [markdown]
# ### 1. Constructing the Boxplot

# %% [markdown]
# #### 2.1 `plt.figure`(figsize=(15, 4))
#
# - Creates a new figure for the plot with a size of 15 inches wide and 4 inches tall.

# %% [markdown]
# ### 2.2 `plt.boxplot`(df['air_time'], vert=False)
#
# - Creates a horizontal boxplot for the air_time column.
#
# - `vert=False` indicates that boxplot should be horizontal!

# %% [markdown]
# ### 2.3 `plt.grid`(alpha=.3)
#
# - It adds a grid to the plot by drawing light lines at major tick marks on both axes (default behavior).
#
# - if alpha is higher, background lines become thicker which my disrupt the visibility of the plot.

# %% [markdown]
# ### 2.4 `plt.title`('Boxplot for air_time column.', size=20, pad=20)
#
# - Sets the plot title:
#
# - font size = 20
#
# - `pad` = padding space between title and the plot.

# %% [markdown]
# ### 2.5 `plt.xticks`(np.arange(0, df.air_time.max() + 20, 20))
#
# Customizes x-axis ticks.
#
# - Uses np.arange() to generate values starting from 0 to the maximum air time + 20, stepping by 20.

# %% [markdown]
# ### 2.6 `plt.ylabel`('air_time')
#
# - Labels the y-axis with 'air_time'.

# %% [markdown]
# ### 2.7 `plt.yticks`([])
#
# - Removes tick marks from the y-axis since the boxplot is horizontal.

# %% [markdown]
# ### How to Read a Boxplot?
#
# A boxplot visualizes key aspects of the data distribution:
#
# 1) __Median__ (middle line of the box): This is the `central value` of the dataset (calculated earlier as _air_time_median).
#
# 2) __Interquartile Range (IQR)__  (box edges):
#
# -  __Lower edge__ : First quartile (Q1, 25th percentile).
#
# - __Upper edge__ : Third quartile (Q3, 75th percentile).
#
# 3) __Whiskers__ :
#
# - Extend to the smallest and largest values within 1.5 × IQR from the box.
#
# 4) __Outliers__ (dots beyond whiskers):
#
# - Points that fall outside the whisker range, representing unusually small or large values.
#
#
# Introductory box and whisker explanation: mean, median, q1-q4, range https://www.youtube.com/watch?v=b2C9I8HuCe4
#
# Boxplot explnation: https://www.youtube.com/watch?v=MmApBcxSgMk (7 min)

# %% [markdown]
# #### Why Boxplots Are Useful
#
# 1) Detect Outliers: Quickly spot extreme values in air_time.
#
# 2) Summarize Distribution: Understand the spread, central tendency, and variability of air_time at a glance.
#
# 3) Compare Groups: Boxplots are often used to compare distributions across categories.

# %%
df.air_time.describe()
# Out:
# count     327346.0
# mean     150.68646
# std      93.688305
# min           20.0
# 25%           82.0
# 50%          129.0
# 75%          192.0
# max          695.0
# Name: air_time, dtype: Float64

# %% [markdown]
# Let's go over each of these:
# - count speaks for itself,
# - mean is the arithmetic mean of the values in `air_time` column. It's the sum of all values divided by the count.

# %%
df.air_time.sum() / len(df)
# Out:
# 150.68646019807787

# %% [markdown]
# - std is standard deviation of the sample (our data is just the sample!).
#
#
# Remember the variance? It is the measure of dispersion. More precisely, it shows how much, on average, each observation deviates from the population mean.
#
# For the population, it is defined as:
#
# $$\sigma^2 = \frac{\sum\limits_{i=1}^{n}{(x_i - \mu)^2}}{n}$$
#
# where $\mu$ is the population mean, n is the population size.
#
# However, the variance for the sample is:
#
# $$s^2 = \frac{\sum\limits_{i=1}^{N}{(x_i - \bar{x})^2}}{N - 1}$$
#
# where $\bar{x}$ is the sample mean, and N is the sample size.
#
# You're probably wondering why there's an **N-1** in the denominator. Why do we need it?
#
# Well, the variance of a sample is calculated based on the sample mean ($\bar{x}$), and not population mean ($\mu$). Because the sample mean is just an approximation of the population mean, population variance estimation is biased. We have to account for this by using the **N-1** correction. This way, our estimation of the population variance is unbiased. By setting the `ddof` parameter in `np.std` to 1, we introduce this correction.
#
# The issue with the variance is that it is hard to interpret since all the differences between observations and mean are squared. This is the reason why we have to standardize it by taking the square root from it, and we get the standard deviation ($\sigma$).
#
# Pay attention: Panda's `describe` method is taking this correction into account when calculating the value for the standard deviation of our sample.

# %%
import numpy as np
def sample_dispersion(values, correction=True):
    numerator = np.sum((values - np.mean(values))**2)
    if correction is True:
        denominator = len(values) - 1
    else:
        denominator = len(values)
    return np.sqrt(numerator/denominator)

# %%
df.air_time.describe()
# Out:
# count     327346.0
# mean     150.68646
# std      93.688305
# min           20.0
# 25%           82.0
# 50%          129.0
# 75%          192.0
# max          695.0
# Name: air_time, dtype: Float64

# %%
sample_dispersion(df.air_time, correction=True)
# Out:
# 93.6883046590099

# %%
np.std(df.air_time, ddof=1)
# Out:
# 93.6883046590099

# %%
sample_dispersion(df.air_time, correction=False)
# Out:
# 93.68816155602985

# %%
np.std(df.air_time, ddof=0)
# Out:
# 93.68816155602985

# %% [markdown]
# The rest of the descriptive statistics are:
# - `min` and `max`, which are obvious, and
# - quartiles given with `25%`, `50%`, and `75%`.
#
# Okay, so to start talking about quartiles, we shall first go into explaining what quantiles are.
#
# Quantiles split probability distribution in equal parts.
#
# When we talk about quantiles, most common ones are:
# - **Quartiles** - split sorted data in 4 parts (3 quartiles).
# - **Deciles** - split sorted data in 10 parts (9 deciles).
# - **Percentiles** - split sorted data into 100 parts (99 percentiles).
#
# So, quartiles divide numerical data into 4 quarters, so that each quarter is the same size.
# - 1st quartile's value divides data so that it is bigger than 25% of the data and smaller than 75%.
# - 2nd quartile divides data into equal parts (50% or the median).
# - 3rd quartile divides data so that 75% of the data is smaller and 25% of the data has a higher value.

# %%
_arr = np.array([1,2,5,6,4,2,6,7,10,3])

# %% [markdown]
# How do we get quartiles? We use NumPy's `quantile` method. The second argument is the list of splitting points. Let's see an example:

# %%
np.quantile(_arr, q=[.25,.5,.75])
# Out:
# array([2.25, 4.5 , 6.  ])

# %% [markdown]
# Why is this so important? Well, there are 3 main measures of central tendency:
# - mean,
# - median, and
# - mode.
#
# Each of these gives just a part of the perspective when looking at the distribution of the data.
#
# Let's go back to our `air_time` and see the values of these measures.

# %%
df.air_time.describe()
# Out:
# count     327346.0
# mean     150.68646
# std      93.688305
# min           20.0
# 25%           82.0
# 50%          129.0
# 75%          192.0
# max          695.0
# Name: air_time, dtype: Float64

# %%
_air_time_mean = np.mean(df.air_time)
_air_time_median = np.median(df.air_time)

plt.figure(figsize=(10, 4))
plt.boxplot(df['air_time'], vert=False);
plt.grid(alpha=.3)
plt.title('Boxplot for air_time column.', size=20, pad=20)
plt.xticks(np.arange(0, df.air_time.max()+20, 20));
plt.ylabel('air_time')
plt.yticks([]);

# lets draw the mean and median
ymin, ymax = plt.gca().get_ylim()
plt.vlines(x=[_air_time_mean], ymin=ymin, ymax=ymax, color='red', label='mean')
plt.vlines(x=[_air_time_median], ymin=ymin, ymax=ymax, color='green', label='median')

# plot the legend
plt.legend(framealpha=.0);

# %% [markdown]
# Here we can see that the mean is shifted to the left. It has a higher value than the median. This happens when the distribution is rightly skewed, i.e., there are outliers on the right end. Outliers affect mean more than median, so in case there are outliers, median should be used as a better representation of average. This can easily happen on the other side of the distribution when the mean is lower in value than the median. This shows that the distribution is left skewed, and the median is also a good representation of the average value.
#
# We have mentioned mode, and it is specific in a way that it shows the most repetitive value in the data. When we are talking about nominal and ordinal variables, this is possible. However, doing this for other types of variables is not possible. This is why we will use `mode` in a different example. Here, `mode` is named **top**.

# %% [markdown]
# ***

# %% [markdown]
# ### Explanation of the unknown parts of the code above:

# %% [markdown]
# 1. ymin, ymax = plt.gca().get_ylim()
#
# - `plt.gca()` - Gets the current axes object (the plot itself). plt.gca() stands for "__Get Current Axes.__"
#
# - `get_ylim()`: Gets the minimum and maximum y-values (limits) of the plot. These are used to draw vertical lines for the mean and median.

# %% [markdown]
# 2.
#
# plt.vlines(x=[_air_time_mean], ymin=ymin, ymax=ymax, color='red', label='mean')
#
# plt.vlines(x=[_air_time_median], ymin=ymin, ymax=ymax, color='green', label='median')

# %% [markdown]
# - `plt.vlines()`: Draws vertical lines on the plot.
#
# - x= [_air_time_mean] : The x-coordinate of the line is the mean of air_time.
#
# - `ymin, ymax`: Specifies the start and end of the line along the y-axis (spans the height of the plot).

# %% [markdown]
# ***
#
# How it's `plt.gca()` represented?

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [4, 5, 6])  # A simple line plot
plt.title("Title")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)

# %% [markdown]
# 1 . What Can You Do with `plt.gca()`?
#
# ### The Axes object gives you control over various plot elements. For example:

# %%
# 1. Get or Adjust Axis Limits

ax = plt.gca()  # Get the current Axes object
xmin, xmax = ax.get_xlim()  # Get current x-axis limits
ymin, ymax = ax.get_ylim()  # Get current y-axis limits

print(f"x-axis range: {xmin} to {xmax}")
print(f"y-axis range: {ymin} to {ymax}")

# Adjust the limits
ax.set_xlim(0, 5)  # Change x-axis range
ax.set_ylim(0, 10)  # Change y-axis range
# Out:
# x-axis range: 0.0 to 1.0
# y-axis range: 0.0 to 1.0
# (0.0, 10.0)

# %% [markdown]
# Back to our stuff:

# %%
df[['carrier', 'flight', 'origin', 'dest']].describe()
# Out:
#                       carrier  flight               origin  \
# count                  327346  327346               327346
# unique                     16    3835                    3
# top     United Air Lines Inc.      15  Newark Liberty Intl
# freq                    57782     956               117127
#
#                                    dest
# count                            327346
# unique                              104
# top     Hartsfield Jackson Atlanta Intl
# freq                              16837

# %% [markdown]
# Let's try to view distribution of the `air_time` column.
#
# Let's try putting both graphs in the same figure.

# %%
_air_time_mean = np.mean(df.air_time)
_air_time_median = np.median(df.air_time)

# %%
# we have to take figure and axes
fig, axes = plt.subplots(ncols=1, nrows=2, figsize=(15, 5), sharex=True)

# flatten for easier indexing
axes = axes.flatten()

# plotting first chart
axes[0].hist(df.air_time,bins=200, alpha=0.3)

# plotting first chart
axes[0].hist(df.air_time, bins=200, alpha=.3)
axes[0].set_title('Distribution of air_time.', size=20, pad=20)
axes[0].grid(alpha=.3)

ymin, ymax = axes[0].get_ylim()
axes[0].vlines(x=[_air_time_mean], ymin=ymin, ymax=ymax, color='red', label='mean')
axes[0].vlines(x=[_air_time_median], ymin=ymin, ymax=ymax, color='green', label='median')
axes[0].legend(framealpha=.0);

# plotting second chart
axes[1].boxplot(df['air_time'], vert=False);
axes[1].grid(alpha=.3)
axes[1].set_xlabel('air_time')
axes[1].set_xticks(np.arange(0, df.air_time.max()+20, 20));
axes[1].set_yticks([]);

ymin, ymax = axes[1].get_ylim()
axes[1].vlines(x=[_air_time_mean], ymin=ymin, ymax=ymax, color='red', label='mean')
axes[1].vlines(x=[_air_time_median], ymin=ymin, ymax=ymax, color='green', label='median')
axes[1].legend(framealpha=.0);

# %%
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1       517             515          2       830
# 1  2013      1    1       533             529          4       850
# 2  2013      1    1       542             540          2       923
# 3  2013      1    1       544             545         -1      1004
# 4  2013      1    1       554             600         -6       812
#
#    sched_arr_time  arr_delay                 carrier flight tailnum  \
# 0             819         11   United Air Lines Inc.   1545  N14228
# 1             830         20   United Air Lines Inc.   1714  N24211
# 2             850         33  American Airlines Inc.   1141  N619AA
# 3            1022        -18         JetBlue Airways    725  N804JB
# 4             837        -25    Delta Air Lines Inc.    461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental       227      1400
# 1           La Guardia     George Bush Intercontinental       227      1416
# 2  John F Kennedy Intl                       Miami Intl       160      1089
# 3  John F Kennedy Intl                              BQN       183      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl       116       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %%
plt.figure(figsize=(15, 5))
plt.scatter(x=df.distance, y=df.air_time, s=1, alpha=.2)
plt.xlabel('distance')
plt.ylabel('air_time')
plt.title('How distance affects air time.', size=20, pad=20)
plt.grid(alpha=.3)
plt.xticks(np.arange(0, df.distance.max()+20, 250));

# %% [markdown]
# Who would say that the distance between the place of departure and arrival does indeed affect the time in the air?
#
# Obviously, there are some big distance flights. Shall we take a look at these?

# %%
df[df.distance > 4000]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 162     2013      1    1       857             900         -3      1516
# 379     2013      1    1      1344            1344          0      2005
# 1061    2013      1    2       909             900          9      1525
# 1280    2013      1    2      1344            1344          0      1940
# 1992    2013      1    3       914             900         14      1504
# ...      ...    ...  ...       ...             ...        ...       ...
# 325120  2013      9   28      1327            1329         -2      1710
# 325676  2013      9   29       957            1000         -3      1405
# 325882  2013      9   29      1420            1329         51      1817
# 326657  2013      9   30       959            1000         -1      1438
# 326838  2013      9   30      1335            1329          6      1802
#
#         sched_arr_time  arr_delay                 carrier flight tailnum  \
# 162               1530        -14  Hawaiian Airlines Inc.     51  N380HA
# 379               1944         21   United Air Lines Inc.     15  N76065
# 1061              1530         -5  Hawaiian Airlines Inc.     51  N380HA
# 1280              1944         -4   United Air Lines Inc.     15  N77066
# 1992              1530        -26  Hawaiian Airlines Inc.     51  N380HA
# ...                ...        ...                     ...    ...     ...
# 325120            1813        -63   United Air Lines Inc.     15  N66057
# 325676            1445        -40  Hawaiian Airlines Inc.     51  N384HA
# 325882            1813          4   United Air Lines Inc.     15  N66057
# 326657            1445         -7  Hawaiian Airlines Inc.     51  N392HA
# 326838            1813        -11   United Air Lines Inc.     15  N76054
#
#                      origin           dest  air_time  distance  hour  minute  \
# 162     John F Kennedy Intl  Honolulu Intl       659      4983     9       0
# 379     Newark Liberty Intl  Honolulu Intl       656      4963    13      44
# 1061    John F Kennedy Intl  Honolulu Intl       638      4983     9       0
# 1280    Newark Liberty Intl  Honolulu Intl       634      4963    13      44
# 1992    John F Kennedy Intl  Honolulu Intl       616      4983     9       0
# ...                     ...            ...       ...       ...   ...     ...
# 325120  Newark Liberty Intl  Honolulu Intl       562      4963    13      29
# 325676  John F Kennedy Intl  Honolulu Intl       580      4983    10       0
# 325882  Newark Liberty Intl  Honolulu Intl       569      4963    13      29
# 326657  John F Kennedy Intl  Honolulu Intl       603      4983    10       0
# 326838  Newark Liberty Intl  Honolulu Intl       604      4963    13      29
#
#                   time_hour
# 162     2013-01-01 09:00:00
# 379     2013-01-01 13:00:00
# 1061    2013-01-02 09:00:00
# 1280    2013-01-02 13:00:00
# 1992    2013-01-03 09:00:00
# ...                     ...
# 325120  2013-09-28 13:00:00
# 325676  2013-09-29 10:00:00
# 325882  2013-09-29 13:00:00
# 326657  2013-09-30 10:00:00
# 326838  2013-09-30 13:00:00
#
# [701 rows x 19 columns]

# %%
df[df.distance > 4000].apply(lambda x: 'Honolulu Intl' in x['dest'], axis=1).all()
# Out:
# True

# %% [markdown]
# These flights are all to Honolulu International Airport. Makes sense.
#
# Let's see what the distribution of flight times is to Honolulu Intl airport if the other airport is JFK in NYC.
#
# But before that, let's see how many flights there are to Honolulu Intl airport, grouped by the place of departure.

# %%
(df.groupby(['origin', 'dest'])['air_time']
   .count()
   .reset_index()
   .rename(columns={'air_time': 'no_of_flights'})
   .query('origin == "Honolulu Intl" | dest == "Honolulu Intl"'))
# Out:
#                   origin           dest  no_of_flights
# 23   John F Kennedy Intl  Honolulu Intl            342
# 170  Newark Liberty Intl  Honolulu Intl            359

# %% [markdown]
# Okay, let's view the distribution of air time for flights from John F Kennedy Intl to Honolulu Intl.

# %%
_df = df.loc[(df.origin == 'John F Kennedy Intl') & (df.dest == 'Honolulu Intl')]

_df
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 162     2013      1    1       857             900         -3      1516
# 1061    2013      1    2       909             900          9      1525
# 1992    2013      1    3       914             900         14      1504
# 2882    2013      1    4       900             900          0      1516
# 3744    2013      1    5       858             900         -2      1519
# ...      ...    ...  ...       ...             ...        ...       ...
# 322116  2013      9   25      1001            1000          1      1508
# 324072  2013      9   27       951            1000         -9      1442
# 324992  2013      9   28       955            1000         -5      1412
# 325676  2013      9   29       957            1000         -3      1405
# 326657  2013      9   30       959            1000         -1      1438
#
#         sched_arr_time  arr_delay                 carrier flight tailnum  \
# 162               1530        -14  Hawaiian Airlines Inc.     51  N380HA
# 1061              1530         -5  Hawaiian Airlines Inc.     51  N380HA
# 1992              1530        -26  Hawaiian Airlines Inc.     51  N380HA
# 2882              1530        -14  Hawaiian Airlines Inc.     51  N384HA
# 3744              1530        -11  Hawaiian Airlines Inc.     51  N381HA
# ...                ...        ...                     ...    ...     ...
# 322116            1445         23  Hawaiian Airlines Inc.     51  N389HA
# 324072            1445         -3  Hawaiian Airlines Inc.     51  N390HA
# 324992            1445        -33  Hawaiian Airlines Inc.     51  N391HA
# 325676            1445        -40  Hawaiian Airlines Inc.     51  N384HA
# 326657            1445         -7  Hawaiian Airlines Inc.     51  N392HA
#
#                      origin           dest  air_time  distance  hour  minute  \
# 162     John F Kennedy Intl  Honolulu Intl       659      4983     9       0
# 1061    John F Kennedy Intl  Honolulu Intl       638      4983     9       0
# 1992    John F Kennedy Intl  Honolulu Intl       616      4983     9       0
# 2882    John F Kennedy Intl  Honolulu Intl       639      4983     9       0
# 3744    John F Kennedy Intl  Honolulu Intl       635      4983     9       0
# ...                     ...            ...       ...       ...   ...     ...
# 322116  John F Kennedy Intl  Honolulu Intl       636      4983    10       0
# 324072  John F Kennedy Intl  Honolulu Intl       629      4983    10       0
# 324992  John F Kennedy Intl  Honolulu Intl       584      4983    10       0
# 325676  John F Kennedy Intl  Honolulu Intl       580      4983    10       0
# 326657  John F Kennedy Intl  Honolulu Intl       603      4983    10       0
#
#                   time_hour
# 162     2013-01-01 09:00:00
# 1061    2013-01-02 09:00:00
# 1992    2013-01-03 09:00:00
# 2882    2013-01-04 09:00:00
# 3744    2013-01-05 09:00:00
# ...                     ...
# 322116  2013-09-25 10:00:00
# 324072  2013-09-27 10:00:00
# 324992  2013-09-28 10:00:00
# 325676  2013-09-29 10:00:00
# 326657  2013-09-30 10:00:00
#
# [342 rows x 19 columns]

# %%
_air_time_mean = np.mean(_df.air_time)
_air_time_median = np.median(_df.air_time)

# we have to take figure and axes
fig, axes = plt.subplots(ncols=1, nrows=2, figsize=(15, 5), sharex=True)

# flatten for easier indexing
axes = axes.flatten()

# plotting first chart
axes[0].hist(_df.air_time, bins=20, alpha=.3)
axes[0].set_title('Distribution of air_time for flights from John F Kennedy Intl to Honolulu Intl', size=20, pad=20)
axes[0].grid(alpha=.3)

ymin, ymax = axes[0].get_ylim()
axes[0].vlines(x=[_air_time_mean], ymin=ymin, ymax=ymax, color='red', label='mean')
axes[0].vlines(x=[_air_time_median], ymin=ymin, ymax=ymax, color='green', label='median')
axes[0].legend(framealpha=.0);

# plotting second chart
axes[1].boxplot(_df.air_time, vert=False);
axes[1].grid(alpha=.3)
axes[1].set_xlabel('air_time')
axes[1].set_xticks(np.arange(0, df.air_time.max()+20, 20));
axes[1].set_yticks([]);

ymin, ymax = axes[1].get_ylim()
axes[1].vlines(x=[_air_time_mean], ymin=ymin, ymax=ymax, color='red', label='mean')
axes[1].vlines(x=[_air_time_median], ymin=ymin, ymax=ymax, color='green', label='median')
axes[1].legend(framealpha=.0);

# %% [markdown]
# Okay, so that' it, but can we check which carriers are having flights on this relation?

# %%
_df.carrier.value_counts()
# Out:
# carrier
# Hawaiian Airlines Inc.    342
# Name: count, dtype: Int64

# %% [markdown]
# Here is another idea!
#
# Let's find the 10 fastest carriers.
#
# Keep in mind that distance is probably measured in miles and flight time is measured in minutes. We'll get the **miles/minute** speed measurement this way. Not **miles/hour**.
#
# We can convert our air time to hours. Let's do that.

# %%
df['speed'] = df.distance / (df.air_time / 60)

# %%
df.groupby('carrier')['speed'].describe()
# Out:
#                                count        mean        std         min  \
# carrier
# AirTran Airways Corporation   3175.0  394.358094  34.192364  280.235294
# Alaska Airlines Inc.           709.0  443.678889  21.720863  367.653061
# American Airlines Inc.       31947.0  417.472739  47.461814     116.875
# Delta Air Lines Inc.         47658.0  418.462807  43.575184  123.296703
# Endeavor Air Inc.            17294.0  345.430398  65.081449   92.459016
# Envoy Air                    25037.0  368.402836  50.822437  131.752577
# ExpressJet Airlines Inc.     51108.0  362.943626  52.243521  123.076923
# Frontier Airlines Inc.         681.0  425.172111  27.778219  349.640288
# Hawaiian Airlines Inc.         342.0  480.357719  15.771798  432.677279
# JetBlue Airways              54049.0  399.971468   64.90478   84.680851
# Mesa Airlines Inc.             544.0  331.969987  62.924261       120.0
# SkyWest Airlines Inc.           29.0  366.320085  25.851527       274.8
# Southwest Airlines Co.       12044.0  400.532009  38.431249  171.864407
# US Airways Inc.              19831.0  341.939717  71.672334        76.8
# United Air Lines Inc.        57782.0  420.883774  48.361956  107.142857
# Virgin America                5116.0  446.174935  23.118805  362.580645
#
#                                     25%         50%         75%         max
# carrier
# AirTran Airways Corporation  371.707317  394.137931  419.449541  531.627907
# Alaska Airlines Inc.         428.928571  444.814815  458.980892  520.288809
# American Airlines Inc.            392.0  423.045685  450.410959  556.457143
# Delta Air Lines Inc.         393.037975  423.776224  448.235294  703.384615
# Endeavor Air Inc.            305.228833   349.90099  392.666667  517.664234
# Envoy Air                    342.089552  374.782609  402.962963       508.0
# ExpressJet Airlines Inc.          328.0  366.857143  401.447368  650.322581
# Frontier Airlines Inc.       406.694561  424.454148   445.87156  498.461538
# Hawaiian Airlines Inc.       470.834646  481.062258  491.743421  515.482759
# JetBlue Airways                   352.0  416.153846  448.439306   557.44186
# Mesa Airlines Inc.               286.25  319.534884  388.571429  473.043478
# SkyWest Airlines Inc.        359.142857  369.705882  375.223881       419.0
# Southwest Airlines Co.        378.26087  402.545455  426.106195  504.269663
# US Airways Inc.              291.818182  337.894737   398.04878  526.666667
# United Air Lines Inc.        396.226415  428.690808   454.12844  550.786517
# Virgin America               429.806094  445.945946  462.616822  519.230769

# %% [markdown]
# Well, to get top N of these, we would have to choose the metric by which we are sorting. How about we plot speed distribution for each of the carriers?
#
# And, while we are trying to do this, let's try switching from using `matplotlib` to `seaborn`!

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x='speed', y='carrier', data=df)
plt.title('Distributions of speeds for each of the carriers.', size=20, pad=20)
plt.grid(alpha=.3)

# %%
sns.histplot(x='distance', bins=10, element='bars', data=df)
sns.despine();
plt.title('Flight distance histogram.', size=20, pad=20);

# %%
# a lot of flights
df[df.carrier == 'United Air Lines Inc.'].shape
# Out:
# (57782, 20)

# %% [markdown]
# Let's create helping dataframe that will contain only the data we are interested in.

# %%
_df = df.loc[(df.carrier == 'United Air Lines Inc.'), ['distance', 'speed']].copy().reset_index(drop=True)

# %%
_df
# Out:
#        distance       speed
# 0          1400  370.044053
# 1          1416  374.273128
# 2           719       287.6
# 3          2475  430.434783
# 4          2565  426.315789
# ...         ...         ...
# 57777       937  457.073171
# 57778       200       300.0
# 57779      1400       480.0
# 57780       200  324.324324
# 57781      2565  483.962264
#
# [57782 rows x 2 columns]

# %% [markdown]
# The NumPy `histogram` method is able to create a histogram for a given array, in this case the **distance**. It returns counts per bin and bin edges. The bin edges array is just an array with increasing values where the bins are created.

# %%
_hist, _bin_edges = np.histogram(_df['distance'], bins=30)

# %%
_bin_edges
# Out:
# array([116.0, 277.56666666666666, 439.1333333333333, 600.7,
#        762.2666666666667, 923.8333333333333, 1085.4, 1246.9666666666667,
#        1408.5333333333333, 1570.1, 1731.6666666666665, 1893.2333333333333,
#        2054.8, 2216.366666666667, 2377.9333333333334, 2539.5,
#        2701.0666666666666, 2862.633333333333, 3024.2, 3185.7666666666664,
#        3347.333333333333, 3508.9, 3670.4666666666667, 3832.0333333333333,
#        3993.6, 4155.166666666666, 4316.733333333334, 4478.3,
#        4639.866666666667, 4801.433333333333, 4963.0], dtype=object)

# %%
_hist
# Out:
# array([ 3307,  1866,     3,  6853,     2, 11955,   267,  4991,  3878,
#         5025,    68,     0,  1111,  1990,  9371,  6728,     0,     0,
#            0,     0,     8,     0,     0,     0,     0,     0,     0,
#            0,     0,   359], dtype=int64)

# %%
sns.histplot(x='distance', bins=_bin_edges, data=_df)
sns.despine();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 sns.histplot(x='distance', bins=_bin_edges, data=_df)
#       2 sns.despine();
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)
#    1446         **kwargs,
#    1447     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\distributions.py:669, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     660 if element == "bars" and "linewidth" not in plot_kws:
#     661
#     662     # Now we handle linewidth, which depends on the scaling of the plot
#     663
#     664     # We will base everything on the minimum bin width
#     665     hist_metadata = pd.concat([
#     666         # Use .items for generality over dict or df
#     667         h.index.to_frame() for _, h in histograms.items()
#     668     ]).reset_index(drop=True)
# --> 669     thin_bar_idx = hist_metadata["widths"].idxmin()
#     670     binwidth = hist_metadata.loc[thin_bar_idx, "widths"]
#     671     left_edge = hist_metadata.loc[thin_bar_idx, "edges"]
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:2460, in Series.idxmin(self, axis, skipna, *args, **kwargs)
#    2396 """
#    2397 Return the row label of the minimum value.
#    2398
#    (...)
#    2456 nan
#    2457 """
#    2458 # error: Argument 1 to "argmin" of "IndexOpsMixin" has incompatible type "Union
#    2459 # [int, Literal['index', 'columns']]"; expected "Optional[int]"
# -> 2460 i = self.argmin(axis, skipna, *args, **kwargs)  # type: ignore[arg-type]
#    2461 if i == -1:
#    2462     return np.nan
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\base.py:742, in IndexOpsMixin.argmin(self, axis, skipna, *args, **kwargs)
#     738         return delegate.argmin()
#     739 else:
#     740     # error: Incompatible return value type (got "Union[int, ndarray]", expected
#     741     # "int")
# --> 742     return nanops.nanargmin(  # type: ignore[return-value]
#     743         delegate, skipna=skipna
#     744     )
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:91, in disallow.__call__.<locals>._f(*args, **kwargs)
#      89 if any(self.check(obj) for obj in obj_iter):
#      90     f_name = f.__name__.replace("nan", "")
# ---> 91     raise TypeError(
#      92         f"reduction operation '{f_name}' not allowed for this dtype"
#      93     )
#      94 try:
#      95     with np.errstate(invalid="ignore"):
#
# TypeError: reduction operation 'argmin' not allowed for this dtype

# %% [markdown]
# Pandas has a method that can be used to create a Series that will hold the bin for each of the observations.

# %%
pd.cut(_df['distance'], _bin_edges)
# Out:
# 0        (1246.967, 1408.533]
# 1          (1408.533, 1570.1]
# 2            (600.7, 762.267]
# 3          (2377.933, 2539.5]
# 4          (2539.5, 2701.067]
#                  ...
# 57777       (923.833, 1085.4]
# 57778        (116.0, 277.567]
# 57779    (1246.967, 1408.533]
# 57780        (116.0, 277.567]
# 57781      (2539.5, 2701.067]
# Name: distance, Length: 57782, dtype: category
# Categories (30, interval[float64, right]): [(116.0, 277.567] < (277.567, 439.133] < (439.133, 600.7] < (600.7, 762.267] ... (4316.733, 4478.3] < (4478.3, 4639.867] < (4639.867, 4801.433] < (4801.433, 4963.0]]

# %% [markdown]
# Additionally, we will select the right (inclusive) edge for easier interpretation and create the series.
#
# This is the new one, with the same index as the helping data frame, plus we are giving it a new name.

# %%
(pd.Series(pd.cut(_df['distance'], _bin_edges).apply(lambda x: x.right), 
           name='bin', 
           index=_df.index))
# Out:
# 0        1408.533
# 1        1570.100
# 2         762.267
# 3        2539.500
# 4        2701.067
#            ...
# 57777    1085.400
# 57778     277.567
# 57779    1408.533
# 57780     277.567
# 57781    2701.067
# Name: bin, Length: 57782, dtype: category
# Categories (30, float64): [277.567 < 439.133 < 600.700 < 762.267 ... 4478.300 < 4639.867 < 4801.433 < 4963.000]

# %% [markdown]
# Okay, let's add this to the existing helping data frame. This is one of the ways to perform the 'merging'. It is done by concatenating. You can concatenate a DataFrame with another DataFrame or with a Series.

# %%
_df
# Out:
#        distance       speed
# 0          1400  370.044053
# 1          1416  374.273128
# 2           719       287.6
# 3          2475  430.434783
# 4          2565  426.315789
# ...         ...         ...
# 57777       937  457.073171
# 57778       200       300.0
# 57779      1400       480.0
# 57780       200  324.324324
# 57781      2565  483.962264
#
# [57782 rows x 2 columns]

# %%
_df1 = pd.concat([
    _df, 
    pd.Series(pd.cut(_df['distance'], _bin_edges).apply(lambda x: x.right), 
              name='bin', 
              index=_df.index)
], axis=1)

print('Just the first 5 rows...')
_df1.head()
# Out:
# Just the first 5 rows...
#    distance       speed       bin
# 0      1400  370.044053  1408.533
# 1      1416  374.273128  1570.100
# 2       719       287.6   762.267
# 3      2475  430.434783  2539.500
# 4      2565  426.315789  2701.067

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5), sharey=True)

axes = axes.flatten()

sns.boxplot(x='speed', y='bin', data=_df1, ax=axes[0])

axes[0].set_ylabel('distance bin')
axes[0].set_title('Distributions of speeds per segments of distance.', size=15, pad=20);

axes[0].set_xticks(list(range(100, 600, 50)))
_y_tick_labels = [x.get_text() for x in axes[0].get_yticklabels()]
axes[0].set_yticklabels([f'{float(x):.0f}' for x in _y_tick_labels]);

axes[0].grid(alpha=.3)

sns.countplot(y='bin', data=_df1, ax=axes[1])
axes[1].set_ylabel('');
axes[1].set_xlabel('log(count)');
axes[1].set_title('Log of counts per distance bin.', size=15, pad=20);
axes[1].set_xscale('log')
axes[1].grid(alpha=.3)

# %% [markdown]
# Well, in general, it seems that the greater the distance, the greater the speed. Makes sense!

# %% [markdown]
# At the beginning, we showed the graphical representation of the missing values. But how did we do it?
#
# There is a `seaborn` method called `heatmap`. It takes tabular data and creates a graphical representation of this table, but instead of showing the values, it colors the cell based on these values.
#
# Example:

# %%
cont_table = {
    'true': {'true': 40, 'false': 20},
    'false': {'true': 20, 'false': 10}
}

_df = pd.DataFrame(cont_table)

_df
# Out:
#        true  false
# true     40     20
# false    20     10

# %%
sns.heatmap(_df);
plt.title('Seaborn heatmap from our DataFrame', size=20, pad=20);

# %% [markdown]
# When checking for missing values in the dataset, we can call Pandas DataFrame method `isna`, which gives us a table of the same dimensions but with boolean values instead of the original ones. `True` is the value of the cell that has the missing values.
#
# This way, we are able to use `seaborn` `heatmap` to represent this table of booleans in an appealing way.
#
# Let's see how we can do this.

# %% [markdown]
# We will load the data once again because we need the original one that had missing values.

# %%
df = pd.read_csv('_data/flights_session06.csv', index_col=0)
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay                 carrier  flight tailnum  \
# 0             819       11.0   United Air Lines Inc.    1545  N14228
# 1             830       20.0   United Air Lines Inc.    1714  N24211
# 2             850       33.0  American Airlines Inc.    1141  N619AA
# 3            1022      -18.0         JetBlue Airways     725  N804JB
# 4             837      -25.0    Delta Air Lines Inc.     461  N668DN
#
#                 origin                             dest  air_time  distance  \
# 0  Newark Liberty Intl     George Bush Intercontinental     227.0      1400
# 1           La Guardia     George Bush Intercontinental     227.0      1416
# 2  John F Kennedy Intl                       Miami Intl     160.0      1089
# 3  John F Kennedy Intl                              BQN     183.0      1576
# 4           La Guardia  Hartsfield Jackson Atlanta Intl     116.0       762
#
#    hour  minute            time_hour
# 0     5      15  2013-01-01 05:00:00
# 1     5      29  2013-01-01 05:00:00
# 2     5      40  2013-01-01 05:00:00
# 3     5      45  2013-01-01 05:00:00
# 4     6       0  2013-01-01 06:00:00

# %% [markdown]
# Let's make a list of column names where we have missing values.
#
# First, get the list of all columns and the number of missing values for each.

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# arr_delay         9430
# air_time          9430
# arr_time          8713
# dep_time          8255
# dep_delay         8255
# tailnum           2512
# year                 0
# origin               0
# minute               0
# hour                 0
# distance             0
# dest                 0
# carrier              0
# flight               0
# month                0
# sched_arr_time       0
# sched_dep_time       0
# day                  0
# time_hour            0
# dtype: int64

# %% [markdown]
# Then we want to sort them in decreasing order and take only those columns that have missing values.

# %%
(df.isna()
 .sum()
 .sort_values(ascending=False)
.where(lambda x: x > 0)
.dropna()
 )
# Out:
# arr_delay    9430.0
# air_time     9430.0
# arr_time     8713.0
# dep_time     8255.0
# dep_delay    8255.0
# tailnum      2512.0
# dtype: float64

# %% [markdown]
# After that we want to store this as a list of column names.

# %%
null_columns =  (df.isna()
                   .sum()
                   .sort_values(ascending=False)
                   .where(lambda x: x > 0)
                   .dropna()
                   .index.to_list())

null_columns
# Out:
# ['arr_delay', 'air_time', 'arr_time', 'dep_time', 'dep_delay', 'tailnum']

# %% [markdown]
# In the end, we create the `heatmap` with this

# %% [markdown]
# Before plotting the `heatmap` here is how the table of booleans looks. Pay attention, it is transposed!

# %%
df[null_columns].isna().sort_values(by=null_columns, ascending=False).T
# Out:
#            1782    1784    2697    2698    3608    3609    4332    6098    \
# arr_delay    True    True    True    True    True    True    True    True
# air_time     True    True    True    True    True    True    True    True
# arr_time     True    True    True    True    True    True    True    True
# dep_time     True    True    True    True    True    True    True    True
# dep_delay    True    True    True    True    True    True    True    True
# tailnum      True    True    True    True    True    True    True    True
#
#            6997    7895    ...  336760  336761  336762  336763  336764  \
# arr_delay    True    True  ...   False   False   False   False   False
# air_time     True    True  ...   False   False   False   False   False
# arr_time     True    True  ...   False   False   False   False   False
# dep_time     True    True  ...   False   False   False   False   False
# dep_delay    True    True  ...   False   False   False   False   False
# tailnum      True    True  ...   False   False   False   False   False
#
#            336765  336766  336767  336768  336769
# arr_delay   False   False   False   False   False
# air_time    False   False   False   False   False
# arr_time    False   False   False   False   False
# dep_time    False   False   False   False   False
# dep_delay   False   False   False   False   False
# tailnum     False   False   False   False   False
#
# [6 rows x 336776 columns]

# %%
fig, ax = plt.subplots(figsize=(10, 5))

# changing the color mapping
rocket_cmap = sns.color_palette("Blues", as_cmap=True)

sns.heatmap(df[null_columns].isna().sort_values(by=null_columns, ascending=False).T, 
            cbar=False,  # disabling color bar on the right
            cmap=rocket_cmap, # setting the new color mapping
            ax=ax # one of the ways how we can explicitly set the destination axis
) 

sns.despine(bottom=True,  left=True) # removing all of the spines
ax.set_xticks([])
ax.set_title('Missing values in our dataset.', size=20);

# %% [markdown]
# So, if we can use `heatmap` to visualize a DataFrame cell values... can we use the same for contigency tables? YES!

# %%
# our carrier/origin contigency table that is normalized by row data
_df = pd.crosstab(index=df['carrier'], columns=df['origin'], normalize='index')

sns.heatmap(_df, annot=True, fmt='.0%')
plt.title('Percentages of flights for each airline depending on the airport of departure.', size=12, pad=20);

# %% [markdown]
# ### Readings and Videos
# - [Matplotlib - Quick start guide](https://matplotlib.org/stable/tutorials/introductory/quick_start.html)
# - [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html)
# - [Visualizing Missing Data with Seaborn Heatmap and Displot](https://datavizpyr.com/visualizing-missing-data-with-seaborn-heatmap-and-displot/)

# %% [markdown]
# ### A highly recommended To Do
# - [Bill Lubanovic, Introducing Python, 1st Edition](https://www.oreilly.com/library/view/introducing-python-2nd/9781492051374/), Chapter 13. Calendars and Clocks.
# - [What are degrees of freedom?!? Seriously.](https://youtu.be/N20rl2llHno)
# - [Variance and Standard Deviation: Why divide by n-1?](https://youtu.be/wpY9o_OyxoQ)
