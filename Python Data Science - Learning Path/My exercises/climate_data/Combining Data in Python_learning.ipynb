# %% [markdown]
# ### This is part of `Python07` session but also it will be useful for refreshing the memory for already learned stuff.

# %% [markdown]
# Lets dive into it:

# %% [markdown]
# #### Combining Data in pandas With `merge()`, `.join()`, and `concat()`.

# %%
import pandas as pd
import numpy as np
import os

# %%
work_dir = os.getcwd()
print(work_dir)
# Out:
# c:\Users\Admin\dss03Python\PY\Python07\climate_data

# %% [markdown]
# ### **1.** pandas merge(): Combining Data on Common Columns or Indices

# %% [markdown]
# merge() is most useful when you want to combine rows that share data.
#
# You can achieve both many-to-one and many-to-many joins with merge(). In a many-to-one join, one of your datasets will have many rows in the merge column that repeat the same values.
#
#  For example, the values could be 1, 1, 3, 5, and 5. At the same time, the merge column in the other dataset won’t have repeated values. Take 1, 3, and 5 as an example.

# %% [markdown]
# When you use merge(), you’ll provide two required arguments:
#
#     1)The left DataFrame
#
#     2)The right DataFrame

# %% [markdown]
# After that, you can provide a number of optional arguments to define how your datasets are merged:
#
# - `how` defines what kind of merge to make. It defaults to `'inner'`, but other possible options include `'outer', 'left', and 'right'`.
#
# - on tells merge() which columns or indices, also called key columns or key indices, you want to join on.
#
# This is optional. If it isn’t specified, and left_index and right_index (covered below) are False, then columns from the two DataFrames that share names will be used as join keys. If you use on, then the column or index that you specify must be present in both objects.

# %% [markdown]
# #### 1a. How to Use merge()

# %% [markdown]
# ### Outer Join
#
# #### With outer joins, you’ll merge your data based on all the keys in the left object, the right object, or both. For keys that only exist in one object, unmatched columns in the other object will be filled in with NaN, which stands for Not a Number.

# %%
climate_temp = pd.read_csv('climate_temp.csv')
climate_precip = pd.read_csv('climate_precip.csv')

# %%
climate_temp.head()
# Out:
#              STATION            STATION_NAME ELEVATION  LATITUDE   LONGITUDE  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806  -116.03694
#
#        DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  DLY-CLDD-BASE55  \
# 0  20100101                6                2            -7777
# 1  20100102                6                2                1
# 2  20100103                6                2                1
# 3  20100104                6                2                1
# 4  20100105                6                2                1
#
#    DLY-CLDD-BASE57  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  DLY-CLDD-BASE72  \
# 0            -7777  ...                0                0                0
# 1            -7777  ...                0                0                0
# 2            -7777  ...                0                0                0
# 3            -7777  ...                0                0                0
# 4            -7777  ...                0                0                0
#
#    DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  DLY-HTDD-BASE55  \
# 0            -7777                1                2                6
# 1            -7777                1                2                6
# 2            -7777                1                2                5
# 3            -7777                1                2                5
# 4            -7777            -7777                2                5
#
#    DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0                7               10               15
# 1                7               10               15
# 2                7               10               15
# 3                7               10               15
# 4                7               10               15
#
# [5 rows x 21 columns]

# %%
climate_precip.head()
# Out:
#              STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100101            -6.66
# 1  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100102            -6.66
# 2  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100103            -6.66
# 3  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100104            -6.66
# 4  GHCND:USC00049099  TWENTYNINE PALMS CA US  20100105            -6.66
#
#    DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666            -66.6            -6.66             -666
# 1             -666            -66.6            -6.66             -666
# 2             -666            -66.6            -6.66             -666
# 3            -9999          -9999.0            -6.66            -9999
# 4            -9999          -9999.0            -6.66            -9999
#
#    DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# 0            -66.6            -6.66  ...                        3
# 1            -66.6            -6.66  ...                        3
# 2            -66.6            -6.66  ...                        3
# 3          -9999.0            -6.66  ...                        3
# 4          -9999.0            -6.66  ...                        3
#
#    DLY-SNWD-PCTALL-GE001WI  DLY-SNWD-PCTALL-GE010WI  DLY-SNWD-PCTALL-GE003WI  \
# 0                    -9999                        0                    -9999
# 1                    -9999                        0                    -9999
# 2                    -9999                        0                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNWD-PCTALL-GE005WI  DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  \
# 0                    -9999                    -9999                    -9999
# 1                    -9999                    -9999                    -9999
# 2                    -9999                    -9999                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    DLY-SNOW-PCTALL-GE100TI  DLY-SNOW-PCTALL-GE030TI  DLY-SNOW-PCTALL-GE050TI
# 0                        0                    -9999                    -9999
# 1                        0                    -9999                    -9999
# 2                        0                    -9999                    -9999
# 3                        0                        0                        0
# 4                        0                        0                        0
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Inner Join

# %% [markdown]
# In this example, I will  use `merge()` with its default arguments, which will result in an inner join.
#
# Remember that in an inner join, `I will lose rows that don’t have a match in the other DataFrame’s key column. `

# %% [markdown]
# With the two datasets loaded into DataFrame objects, I will select a small slice of the precipitation dataset and then use a plain merge() call to do an inner join. This will result in a smaller, more focused dataset:

# %%
precip_one_station = climate_precip.query("STATION == 'GHCND:USC00045721'") 

# or as I did previously 
# more pythonic i guess :)

precip_one_station = climate_precip[climate_precip['STATION'].isin(['GHCND:USC00045721'])]
precip_one_station
# Out:
#                 STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 1460  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1461  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 1462  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 1463  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 1464  GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
# ...                 ...                     ...       ...              ...
# 1820  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101227             0.04
# 1821  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101228             0.04
# 1822  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101229             0.04
# 1823  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101230             0.04
# 1824  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
#
#       DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 1460             -666            -66.6             0.16             -666
# 1461             -666            -66.6             0.16             -666
# 1462             -666            -66.6             0.16             -666
# 1463             -666            -66.6             0.16             -666
# 1464             -666            -66.6             0.17             -666
# ...               ...              ...              ...              ...
# 1820             -666            -66.6             0.15             -666
# 1821             -666            -66.6             0.15             -666
# 1822             -666            -66.6             0.15             -666
# 1823             -666            -66.6             0.15             -666
# 1824             -666            -66.6             0.15             -666
#
#       DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-PRCP-PCTALL-GE100HI  \
# 1460            -66.6             0.44  ...                       11
# 1461            -66.6             0.44  ...                       11
# 1462            -66.6             0.45  ...                       11
# 1463            -66.6             0.45  ...                       11
# 1464            -66.6             0.46  ...                       11
# ...               ...              ...  ...                      ...
# 1820            -66.6             0.44  ...                       12
# 1821            -66.6             0.43  ...                       12
# 1822            -66.6             0.43  ...                       11
# 1823            -66.6             0.43  ...                       11
# 1824            -66.6             0.44  ...                       11
#
#       DLY-SNWD-PCTALL-GE001WI  DLY-SNWD-PCTALL-GE010WI  \
# 1460                        4                        0
# 1461                        4                        0
# 1462                        4                        0
# 1463                        4                        0
# 1464                        4                        0
# ...                       ...                      ...
# 1820                        4                        0
# 1821                        4                        0
# 1822                        4                        0
# 1823                        4                        0
# 1824                        4                        0
#
#       DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 1460                        3                        3
# 1461                        3                        3
# 1462                        3                        3
# 1463                        3                        2
# 1464                        3                        2
# ...                       ...                      ...
# 1820                        3                        3
# 1821                        3                        3
# 1822                        3                        3
# 1823                        3                        3
# 1824                        3                        3
#
#       DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  \
# 1460                        9                        6
# 1461                       10                        6
# 1462                       10                        6
# 1463                       10                        6
# 1464                       10                        6
# ...                       ...                      ...
# 1820                        9                        6
# 1821                        9                        6
# 1822                        9                        6
# 1823                        9                        6
# 1824                        9                        6
#
#       DLY-SNOW-PCTALL-GE100TI  DLY-SNOW-PCTALL-GE030TI  \
# 1460                        0                    -9999
# 1461                        0                    -9999
# 1462                        0                    -9999
# 1463                        0                    -9999
# 1464                        0                    -9999
# ...                       ...                      ...
# 1820                        0                        2
# 1821                        0                        2
# 1822                        0                        2
# 1823                        0                        2
# 1824                        0                        2
#
#       DLY-SNOW-PCTALL-GE050TI
# 1460                    -9999
# 1461                    -9999
# 1462                    -9999
# 1463                    -9999
# 1464                    -9999
# ...                       ...
# 1820                        2
# 1821                        2
# 1822                        2
# 1823                        2
# 1824                        2
#
# [365 rows x 29 columns]

# %% [markdown]
# Lets merge it

# %%
inner_join = pd.merge(precip_one_station,climate_temp)
inner_join
# Out:
# <bound method NDFrame.head of                STATION            STATION_NAME      DATE  DLY-PRCP-25PCTL  \
# 0    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
# ..                 ...                     ...       ...              ...
# 360  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101227             0.04
# 361  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101228             0.04
# 362  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101229             0.04
# 363  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101230             0.04
# 364  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
#
#      DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0               -666            -66.6             0.16             -666
# 1               -666            -66.6             0.16             -666
# 2               -666            -66.6             0.16             -666
# 3               -666            -66.6             0.16             -666
# 4               -666            -66.6             0.17             -666
# ..               ...              ...              ...              ...
# 360             -666            -66.6             0.15             -666
# 361             -666            -66.6             0.15             -666
# 362             -666            -66.6             0.15             -666
# 363             -666            -66.6             0.15             -666
# 364             -666            -66.6             0.15             -666
#
#      DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# 0              -66.6             0.44  ...                0                0
# 1              -66.6             0.44  ...                0                0
# 2              -66.6             0.45  ...                0                0
# 3              -66.6             0.45  ...                0                0
# 4              -66.6             0.46  ...                0                0
# ..               ...              ...  ...              ...              ...
# 360            -66.6             0.44  ...            -7777                0
# 361            -66.6             0.43  ...            -7777                0
# 362            -66.6             0.43  ...            -7777                0
# 363            -66.6             0.43  ...            -7777                0
# 364            -66.6             0.44  ...            -7777                0
#
#      DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  \
# 0                  0                1                3                6
# 1                  0                1                3                6
# 2                  0                1                2                5
# 3                  0                1                2                5
# 4                  0                1                2                5
# ..               ...              ...              ...              ...
# 360                0                1                3                6
# 361                0                1                3                6
# 362                0                1                3                6
# 363                0                1                3                6
# 364                0                1                3                6
#
#      DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0                 10               12               14               19
# 1                 10               11               14               19
# 2                  9               11               14               19
# 3                  9               11               14               19
# 4                  9               11               14               19
# ..               ...              ...              ...              ...
# 360               10               12               15               20
# 361               10               12               15               20
# 362               10               12               15               20
# 363               10               12               15               20
# 364               10               12               15               19
#
# [365 rows x 47 columns]>

# %% [markdown]
# `merge()` defaults to an inner join, and an inner join will discard only those rows that don’t match

# %% [markdown]
# The numbers of rows stayed the same.

# %% [markdown]
# With `merge()`, you also have control over which column(s) to join on. Let’s say that I want to merge both entire datasets, but only on `Station and Date` since the combination of the two will yield a unique value for each row. To do so, you can use the on parameter:

# %%
inner_merged_total = pd.merge(climate_temp,climate_precip, how='inner', on=['STATION','DATE'])
inner_merged_total
# Out:
#                   STATION          STATION_NAME_x ELEVATION  LATITUDE  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# ...                   ...                     ...       ...       ...
# 123000  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 123001  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 123002  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 123003  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 123004  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#          LONGITUDE      DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# 0       -116.03694  20100101                6                2
# 1       -116.03694  20100102                6                2
# 2       -116.03694  20100103                6                2
# 3       -116.03694  20100104                6                2
# 4       -116.03694  20100105                6                2
# ...            ...       ...              ...              ...
# 123000   -118.0711  20101227                4                2
# 123001   -118.0711  20101228                4                2
# 123002   -118.0711  20101229                4                2
# 123003   -118.0711  20101230                4                2
# 123004   -118.0711  20101231                4                2
#
#         DLY-CLDD-BASE55  DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  \
# 0                 -7777            -7777  ...                        3
# 1                     1            -7777  ...                        3
# 2                     1            -7777  ...                        3
# 3                     1            -7777  ...                        3
# 4                     1            -7777  ...                        3
# ...                 ...              ...  ...                      ...
# 123000                1            -7777  ...                       62
# 123001                1            -7777  ...                       62
# 123002                1            -7777  ...                       63
# 123003                1            -7777  ...                       64
# 123004                1            -7777  ...                       64
#
#         DLY-SNWD-PCTALL-GE001WI  DLY-SNWD-PCTALL-GE010WI  \
# 0                         -9999                        0
# 1                         -9999                        0
# 2                         -9999                        0
# 3                             0                        0
# 4                             0                        0
# ...                         ...                      ...
# 123000                    -9999                    -9999
# 123001                    -9999                    -9999
# 123002                    -9999                    -9999
# 123003                    -9999                    -9999
# 123004                    -9999                    -9999
#
#         DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 0                         -9999                    -9999
# 1                         -9999                    -9999
# 2                         -9999                    -9999
# 3                             0                        0
# 4                             0                        0
# ...                         ...                      ...
# 123000                    -9999                    -9999
# 123001                    -9999                    -9999
# 123002                    -9999                    -9999
# 123003                    -9999                    -9999
# 123004                    -9999                    -9999
#
#         DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  \
# 0                         -9999                    -9999
# 1                         -9999                    -9999
# 2                         -9999                    -9999
# 3                             0                        0
# 4                             0                        0
# ...                         ...                      ...
# 123000                    -9999                    -9999
# 123001                    -9999                    -9999
# 123002                    -9999                    -9999
# 123003                    -9999                    -9999
# 123004                    -9999                    -9999
#
#         DLY-SNOW-PCTALL-GE100TI  DLY-SNOW-PCTALL-GE030TI  \
# 0                             0                    -9999
# 1                             0                    -9999
# 2                             0                    -9999
# 3                             0                        0
# 4                             0                        0
# ...                         ...                      ...
# 123000                    -9999                    -9999
# 123001                    -9999                    -9999
# 123002                    -9999                    -9999
# 123003                    -9999                    -9999
# 123004                    -9999                    -9999
#
#         DLY-SNOW-PCTALL-GE050TI
# 0                         -9999
# 1                         -9999
# 2                         -9999
# 3                             0
# 4                             0
# ...                         ...
# 123000                    -9999
# 123001                    -9999
# 123002                    -9999
# 123003                    -9999
# 123004                    -9999
#
# [123005 rows x 48 columns]

# %% [markdown]
# ### Outer Join
#
# #### also known as a full outer join
#
# ##### all rows from both DataFrames will be present in the new DataFrame.
#
# - If a row doesn’t have a match in the other DataFrame based on the key column(s), then I won’t lose the row like you would with an inner join.
#
# - Instead, the row will be in the merged DataFrame, with NaN values filled in where appropriate.

# %%
outer_merged = pd.merge(precip_one_station,climate_temp, how='outer', on=['STATION','DATE'])
outer_merged.dropna()
# Out:
#                STATION          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100102             0.05
# 2    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100103             0.05
# 3    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100104             0.05
# 4    GHCND:USC00045721  MITCHELL CAVERNS CA US  20100105             0.05
# ..                 ...                     ...       ...              ...
# 360  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101227             0.04
# 361  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101228             0.04
# 362  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101229             0.04
# 363  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101230             0.04
# 364  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
#
#      DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0             -666.0            -66.6             0.16           -666.0
# 1             -666.0            -66.6             0.16           -666.0
# 2             -666.0            -66.6             0.16           -666.0
# 3             -666.0            -66.6             0.16           -666.0
# 4             -666.0            -66.6             0.17           -666.0
# ..               ...              ...              ...              ...
# 360           -666.0            -66.6             0.15           -666.0
# 361           -666.0            -66.6             0.15           -666.0
# 362           -666.0            -66.6             0.15           -666.0
# 363           -666.0            -66.6             0.15           -666.0
# 364           -666.0            -66.6             0.15           -666.0
#
#      DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  DLY-CLDD-BASE70  \
# 0              -66.6             0.44  ...                0                0
# 1              -66.6             0.44  ...                0                0
# 2              -66.6             0.45  ...                0                0
# 3              -66.6             0.45  ...                0                0
# 4              -66.6             0.46  ...                0                0
# ..               ...              ...  ...              ...              ...
# 360            -66.6             0.44  ...            -7777                0
# 361            -66.6             0.43  ...            -7777                0
# 362            -66.6             0.43  ...            -7777                0
# 363            -66.6             0.43  ...            -7777                0
# 364            -66.6             0.44  ...            -7777                0
#
#      DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  DLY-HTDD-BASE50  \
# 0                  0                1                3                6
# 1                  0                1                3                6
# 2                  0                1                2                5
# 3                  0                1                2                5
# 4                  0                1                2                5
# ..               ...              ...              ...              ...
# 360                0                1                3                6
# 361                0                1                3                6
# 362                0                1                3                6
# 363                0                1                3                6
# 364                0                1                3                6
#
#      DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  DLY-HTDD-NORMAL
# 0                 10               12               14               19
# 1                 10               11               14               19
# 2                  9               11               14               19
# 3                  9               11               14               19
# 4                  9               11               14               19
# ..               ...              ...              ...              ...
# 360               10               12               15               20
# 361               10               12               15               20
# 362               10               12               15               20
# 363               10               12               15               20
# 364               10               12               15               19
#
# [365 rows x 48 columns]

# %% [markdown]
# ### Left Join
#
# Using a left outer join will leave your new merged DataFrame with all rows from the left DataFrame, while discarding rows from the right DataFrame that don’t have a match in the key column of the left DataFrame.
#
# Example in action:

# %%
left_join = pd.merge(climate_temp, precip_one_station, how='left',on='DATE')
#It is expected that my climate_temp data frame will be full, and it will be joined with precip_station_one specified on DATE column from precip_station_one

left_join
# Out:
#                 STATION_x          STATION_NAME_x ELEVATION  LATITUDE  \
# 0       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 1       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 2       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 3       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# 4       GHCND:USC00049099  TWENTYNINE PALMS CA US       602  34.12806
# ...                   ...                     ...       ...       ...
# 127015  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127016  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127017  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127018  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
# 127019  GHCND:USC00046006  MOUNT WILSON CBS CA US    1740.4   34.2308
#
#          LONGITUDE      DATE  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# 0       -116.03694  20100101                6                2
# 1       -116.03694  20100102                6                2
# 2       -116.03694  20100103                6                2
# 3       -116.03694  20100104                6                2
# 4       -116.03694  20100105                6                2
# ...            ...       ...              ...              ...
# 127015   -118.0711  20101227                4                2
# 127016   -118.0711  20101228                4                2
# 127017   -118.0711  20101229                4                2
# 127018   -118.0711  20101230                4                2
# 127019   -118.0711  20101231                4                2
#
#         DLY-CLDD-BASE55  DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  \
# 0                 -7777            -7777  ...                       11
# 1                     1            -7777  ...                       11
# 2                     1            -7777  ...                       11
# 3                     1            -7777  ...                       11
# 4                     1            -7777  ...                       11
# ...                 ...              ...  ...                      ...
# 127015                1            -7777  ...                       12
# 127016                1            -7777  ...                       12
# 127017                1            -7777  ...                       11
# 127018                1            -7777  ...                       11
# 127019                1            -7777  ...                       11
#
#         DLY-SNWD-PCTALL-GE001WI  DLY-SNWD-PCTALL-GE010WI  \
# 0                             4                        0
# 1                             4                        0
# 2                             4                        0
# 3                             4                        0
# 4                             4                        0
# ...                         ...                      ...
# 127015                        4                        0
# 127016                        4                        0
# 127017                        4                        0
# 127018                        4                        0
# 127019                        4                        0
#
#         DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 0                             3                        3
# 1                             3                        3
# 2                             3                        3
# 3                             3                        2
# 4                             3                        2
# ...                         ...                      ...
# 127015                        3                        3
# 127016                        3                        3
# 127017                        3                        3
# 127018                        3                        3
# 127019                        3                        3
#
#         DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  \
# 0                             9                        6
# 1                            10                        6
# 2                            10                        6
# 3                            10                        6
# 4                            10                        6
# ...                         ...                      ...
# 127015                        9                        6
# 127016                        9                        6
# 127017                        9                        6
# 127018                        9                        6
# 127019                        9                        6
#
#         DLY-SNOW-PCTALL-GE100TI  DLY-SNOW-PCTALL-GE030TI  \
# 0                             0                    -9999
# 1                             0                    -9999
# 2                             0                    -9999
# 3                             0                    -9999
# 4                             0                    -9999
# ...                         ...                      ...
# 127015                        0                        2
# 127016                        0                        2
# 127017                        0                        2
# 127018                        0                        2
# 127019                        0                        2
#
#         DLY-SNOW-PCTALL-GE050TI
# 0                         -9999
# 1                         -9999
# 2                         -9999
# 3                         -9999
# 4                         -9999
# ...                         ...
# 127015                        2
# 127016                        2
# 127017                        2
# 127018                        2
# 127019                        2
#
# [127020 rows x 49 columns]

# %%
climate_temp.shape
# Out:
# (127020, 21)

# %% [markdown]
# left_merged has 127,020 rows, matching the number of rows in the left DataFrame, climate_temp. To prove that this only holds for the left DataFrame, run the same code, but change the position of precip_one_station and climate_temp:

# %%
# same code as above:

left_join = pd.merge(precip_one_station, climate_temp, how='left',on='DATE')
left_join
# Out:
#                 STATION_x          STATION_NAME_x      DATE  DLY-PRCP-25PCTL  \
# 0       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 1       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 2       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 3       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# 4       GHCND:USC00045721  MITCHELL CAVERNS CA US  20100101             0.04
# ...                   ...                     ...       ...              ...
# 127015  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
# 127016  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
# 127017  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
# 127018  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
# 127019  GHCND:USC00045721  MITCHELL CAVERNS CA US  20101231             0.04
#
#         DLY-SNWD-25PCTL  DLY-SNOW-25PCTL  DLY-PRCP-50PCTL  DLY-SNWD-50PCTL  \
# 0                  -666            -66.6             0.16             -666
# 1                  -666            -66.6             0.16             -666
# 2                  -666            -66.6             0.16             -666
# 3                  -666            -66.6             0.16             -666
# 4                  -666            -66.6             0.16             -666
# ...                 ...              ...              ...              ...
# 127015             -666            -66.6             0.15             -666
# 127016             -666            -66.6             0.15             -666
# 127017             -666            -66.6             0.15             -666
# 127018             -666            -66.6             0.15             -666
# 127019             -666            -66.6             0.15             -666
#
#         DLY-SNOW-50PCTL  DLY-PRCP-75PCTL  ...  DLY-CLDD-NORMAL  \
# 0                 -66.6             0.44  ...                0
# 1                 -66.6             0.44  ...                0
# 2                 -66.6             0.44  ...            -7777
# 3                 -66.6             0.44  ...            -7777
# 4                 -66.6             0.44  ...                0
# ...                 ...              ...  ...              ...
# 127015            -66.6             0.44  ...                0
# 127016            -66.6             0.44  ...                0
# 127017            -66.6             0.44  ...                0
# 127018            -66.6             0.44  ...                0
# 127019            -66.6             0.44  ...            -7777
#
#         DLY-CLDD-BASE70  DLY-CLDD-BASE72  DLY-HTDD-BASE40  DLY-HTDD-BASE45  \
# 0                     0                0            -7777                1
# 1                     0                0                1                2
# 2                     0                0                0            -7777
# 3                     0                0                0                0
# 4                     0                0                1                3
# ...                 ...              ...              ...              ...
# 127015                0                0                1                4
# 127016                0                0            -7777                1
# 127017                0                0               18               23
# 127018                0                0            -7777                2
# 127019                0                0                1                3
#
#         DLY-HTDD-BASE50  DLY-HTDD-BASE55  DLY-HTDD-BASE57  DLY-HTDD-BASE60  \
# 0                     2                6                7               10
# 1                     6               10               12               15
# 2                 -7777                2                3                5
# 3                 -7777                1                2                4
# 4                     6               10               12               14
# ...                 ...              ...              ...              ...
# 127015                8               12               14               17
# 127016                3                7                9               12
# 127017               28               33               35               38
# 127018                5               10               11               14
# 127019                6               10               12               14
#
#         DLY-HTDD-NORMAL
# 0                    15
# 1                    20
# 2                    10
# 3                     9
# 4                    19
# ...                 ...
# 127015               22
# 127016               17
# 127017               43
# 127018               19
# 127019               19
#
# [127020 rows x 49 columns]

# %% [markdown]
# ### Right Join
#
# #### The right join, or right outer join, is the __mirror-image__ version of the left join.
# #### With this join, all rows from the right DataFrame will be retained, while rows in the left DataFrame without a match in the key column of the right DataFrame will be discarded.

# %%
right_join = pd.merge(climate_temp,precip_one_station,how='right',on='STATION_NAME')
right_join
# Out:
#                 STATION_x            STATION_NAME ELEVATION LATITUDE  \
# 0       GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 1       GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 2       GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 3       GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 4       GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# ...                   ...                     ...       ...      ...
# 133220  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 133221  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 133222  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 133223  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
# 133224  GHCND:USC00045721  MITCHELL CAVERNS CA US    1325.9  34.9436
#
#         LONGITUDE    DATE_x  DLY-CLDD-BASE45  DLY-CLDD-BASE50  \
# 0       -115.5469  20100101                3                1
# 1       -115.5469  20100102                3                1
# 2       -115.5469  20100103                3                1
# 3       -115.5469  20100104                3                1
# 4       -115.5469  20100105                3                1
# ...           ...       ...              ...              ...
# 133220  -115.5469  20101227                3                1
# 133221  -115.5469  20101228                3                1
# 133222  -115.5469  20101229                3                1
# 133223  -115.5469  20101230                3                1
# 133224  -115.5469  20101231                3                1
#
#         DLY-CLDD-BASE55  DLY-CLDD-BASE57  ...  DLY-PRCP-PCTALL-GE100HI  \
# 0                 -7777            -7777  ...                       11
# 1                 -7777            -7777  ...                       11
# 2                 -7777            -7777  ...                       11
# 3                 -7777            -7777  ...                       11
# 4                 -7777            -7777  ...                       11
# ...                 ...              ...  ...                      ...
# 133220            -7777            -7777  ...                       11
# 133221            -7777            -7777  ...                       11
# 133222            -7777            -7777  ...                       11
# 133223            -7777            -7777  ...                       11
# 133224            -7777            -7777  ...                       11
#
#         DLY-SNWD-PCTALL-GE001WI  DLY-SNWD-PCTALL-GE010WI  \
# 0                             4                        0
# 1                             4                        0
# 2                             4                        0
# 3                             4                        0
# 4                             4                        0
# ...                         ...                      ...
# 133220                        4                        0
# 133221                        4                        0
# 133222                        4                        0
# 133223                        4                        0
# 133224                        4                        0
#
#         DLY-SNWD-PCTALL-GE003WI  DLY-SNWD-PCTALL-GE005WI  \
# 0                             3                        3
# 1                             3                        3
# 2                             3                        3
# 3                             3                        3
# 4                             3                        3
# ...                         ...                      ...
# 133220                        3                        3
# 133221                        3                        3
# 133222                        3                        3
# 133223                        3                        3
# 133224                        3                        3
#
#         DLY-SNOW-PCTALL-GE001TI  DLY-SNOW-PCTALL-GE010TI  \
# 0                             9                        6
# 1                             9                        6
# 2                             9                        6
# 3                             9                        6
# 4                             9                        6
# ...                         ...                      ...
# 133220                        9                        6
# 133221                        9                        6
# 133222                        9                        6
# 133223                        9                        6
# 133224                        9                        6
#
#         DLY-SNOW-PCTALL-GE100TI  DLY-SNOW-PCTALL-GE030TI  \
# 0                             0                    -9999
# 1                             0                    -9999
# 2                             0                    -9999
# 3                             0                    -9999
# 4                             0                    -9999
# ...                         ...                      ...
# 133220                        0                        2
# 133221                        0                        2
# 133222                        0                        2
# 133223                        0                        2
# 133224                        0                        2
#
#         DLY-SNOW-PCTALL-GE050TI
# 0                         -9999
# 1                         -9999
# 2                         -9999
# 3                         -9999
# 4                         -9999
# ...                         ...
# 133220                        2
# 133221                        2
# 133222                        2
# 133223                        2
# 133224                        2
#
# [133225 rows x 49 columns]

# %% [markdown]
# ## pandas `concat()`: Combining Data Across Rows or Columns

# %% [markdown]
# When you concatenate datasets, you can specify the axis along which you’ll concatenate.

# %% [markdown]
# ### __pd.concat( )__ parameters:
#
# - objs - takes any sequence—typically a list—of Series or DataFrame objects to be concatenated. You can also provide a dictionary
#
# - `axis` represents the axis that you’ll concatenate along. The default value is 0, which concatenates along the index, or row axis. !!!!
#
# - join is similar to the how parameter in the other techniques, but it only accepts the values inner or outer.  The default value is outer, which preserves data, while inner would eliminate data that doesn’t have a match in the other datase

# %% [markdown]
# #### Examples

# %% [markdown]
# #### First of all, __basic concatenation__ along the default axis using the DataFrames that I've been playing with throughout this tutorial:

# %%
double_precip = pd.concat([precip_one_station,precip_one_station],ignore_index=True)


#ignore_index=True reset the index start 0 step 1
# Out:
# 0      False
# 365     True
# dtype: bool

# %% [markdown]
# As noted before, if you concatenate along axis 0 (rows) but have labels in axis 1 (columns) that don’t match, then those columns will be added and filled in with NaN values. This results in an outer join:

# %%
outer_joined =pd.concat([climate_precip,climate_temp])
outer_joined.shape
# Out:
# (278130, 47)

# %% [markdown]
# With these two DataFrames, since you’re just concatenating along rows, very few columns have the same name. That means you’ll see a lot of columns with `NaN` values.

# %% [markdown]
# So if I wanted to drop these NaN's I could perform the inner join.

# %%
outer_joined =pd.concat([climate_precip,climate_temp], join='inner')
outer_joined.shape
# Out:
# (278130, 3)

# %% [markdown]
# Previous shape: (278130, 47)
#
# Current shape: (278130, 3) -> with `inner` join
#
#
# Using the inner join, I will be left with only those columns that the original DataFrames have in common: `STATION, STATION_NAME, and DATE`.

# %% [markdown]
# Now we have a new data frame that keeps only the same columns from both data frames!

# %% [markdown]
# Using the __axis__ parameter:

# %%
outer_joined = pd.concat([climate_precip,climate_temp], axis=1, join='inner')
outer_joined.shape

# Now, data frame has columns from both data frames! We did this bt setting the axis to (1) , which means 'columns' , 0 is for 'rows'. 

# i could also write it as: (axis='columns') but i like numerical more
# Out:
# (127020, 50)
